# %% [markdown]
# POUTINE _____________________________________________________________________________________________

# %% [markdown]
# ./poutine analyze_local . --format json > tools_output/poutine/findings.json

# %%
import json
from pathlib import Path
from collections import defaultdict

# Input and output paths
input_file = Path("../tools_output/poutine/findings.json")
output_dir = Path("../tools_output/poutine/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Load raw findings
with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

all_findings = data.get("findings", [])

# Group findings by workflow file
grouped = defaultdict(list)
for finding in all_findings:
    meta = finding.get("meta", {})
    path = meta.get("path")
    if not path:
        continue

    workflow_file = Path(path).name

    # Extract fields exactly as reported
    grouped[workflow_file].append({
        "rule_id": finding.get("rule_id", ""),
        "line": str(meta["line"]) if "line" in meta else "",
        "column": "",  # poutine does not give column
        "job": meta.get("job", ""),
        "step": meta.get("step", ""),
        "details": meta.get("details", ""),
        "event_triggers": meta.get("event_triggers", []),
    })

# Save per-workflow JSON files for workflows with issues
saved_files = 0
for workflow_file, findings in grouped.items():
    rule_summary = {}
    for f in findings:
        rule_id = f.get("rule_id")
        if rule_id:
            rule_summary[rule_id] = rule_summary.get(rule_id, 0) + 1

    output_data = {
        "workflow": workflow_file,
        "tool": "poutine",
        "summary": {
            "total_findings": len(findings),
            "by_rule": rule_summary
        },
        "findings": findings
    }

    output_path = output_dir / f"{workflow_file}.json"
    with open(output_path, "w", encoding="utf-8") as f_out:
        json.dump(output_data, f_out, indent=2)
    saved_files += 1

print(f"Saved {saved_files} workflow files to {output_dir}")
# Out:
# Saved 91 workflow files to ../tools_output/poutine/workflow_with_issues

# %%
import json
from pathlib import Path

with open("../tools_output/poutine/findings.json") as f:
    data = json.load(f)

for f in data["findings"]:
    if f["rule_id"] == "default_permissions_on_risky_events":
        print(f)
# Out:
# {'meta': {'event_triggers': ['issue_comment'], 'path': '.github/workflows/electron_electron__issue-commented.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['issue_comment'], 'path': '.github/workflows/excalidraw_excalidraw__autorelease-preview.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['issue_comment'], 'path': '.github/workflows/facebook_facebook-android-sdk__needs-attention.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['issue_comment'], 'path': '.github/workflows/facebook_facebook-ios-sdk__needs-attention.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['issue_comment', 'workflow_dispatch'], 'path': '.github/workflows/NVIDIA_cutlass__blossom-ci.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['issues', 'pull_request_target'], 'path': '.github/workflows/ohmyzsh_ohmyzsh__project.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/NVIDIA_cutlass__labeler.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/airbnb_javascript__rebase.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/airbnb_javascript__require-allow-edits.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/electron_electron__pull-request-labeled.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/facebook_react__compiler_discord_notify.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/facebook_react__runtime_discord_notify.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/facebook_react__shared_label_core_team_prs.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/freeCodeCamp_freeCodeCamp__github-autoclose.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/freeCodeCamp_freeCodeCamp__github-no-i18n-via-prs.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/freeCodeCamp_freeCodeCamp__github-no-web-commits.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/freeCodeCamp_freeCodeCamp__github-spam.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/google_blockly__tag_module_cleanup.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}
# {'meta': {'event_triggers': ['pull_request_target'], 'path': '.github/workflows/vercel_next.js__cancel.yml'}, 'purl': 'pkg:github/madjda32-del/github-actions-security', 'rule_id': 'default_permissions_on_risky_events'}

# %% [markdown]
# ACTIONLINT ____________________________________________________________________________________

# %% [markdown]
# ./actionlint .github/workflows/*.yml > tools_output/actionlint/findings.txt

# %%
import os
import re
import json
import subprocess
from pathlib import Path
from collections import defaultdict

# Paths
WORKFLOW_DIR = "../.github/workflows"
ACTIONLINT = "./../../tools/actionlint/actionlint"
OUTPUT_DIR = Path("../tools_output/actionlint/workflow_with_issues")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

total_files_with_findings = 0

for file in sorted(os.listdir(WORKFLOW_DIR)):
    if file.endswith((".yml", ".yaml")):
        file_path = os.path.join(WORKFLOW_DIR, file)

        # Run actionlint on a single file
        try:
            completed = subprocess.run(
                [ACTIONLINT, file_path],
                capture_output=True,
                text=True
            )
            stdout = completed.stdout.strip()
            if not stdout:
                continue  # No findings, skip

            findings = []
            for line in stdout.splitlines():
                # Example: ../.github/workflows/foo.yml:8:1: Some issue
                match = re.match(rf".+?{re.escape(file)}:(\d+):(\d+):\s+(.*)", line)
                if match:
                    line_num, col_num, message = match.groups()
                    findings.append({
                        "line": int(line_num),
                        "column": int(col_num),
                        "message": message.strip()
                    })

            if findings:
                output_data = {
                    "workflow": file,
                    "tool": "actionlint",
                    "summary": {
                        "total_findings": len(findings)
                    },
                    "findings": findings
                }

                output_path = OUTPUT_DIR / f"{file}.json"
                with open(output_path, "w", encoding="utf-8") as f_out:
                    json.dump(output_data, f_out, indent=2)
                total_files_with_findings += 1

        except Exception as e:
            print(f"Error processing {file}: {e}")

print(f"Saved findings for {total_files_with_findings} workflow files to {OUTPUT_DIR}")
# Out:
# Saved findings for 162 workflow files to ../tools_output/actionlint/workflow_with_issues

# %% [markdown]
# FRIZBEE _____________________________________________________________________________

# %% [markdown]
# ./frizbee actions -n > tools_output/frizbee/findings.txt

# %%
from pathlib import Path

# Input folder and output file
input_dir = Path("../tools_output/frizbee")
output_file = Path("../tools_output/frizbee/findings.txt")

# Collect all unique lines from all txt files
all_lines = set()
for file_path in sorted(input_dir.glob("*.txt")):
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            all_lines.add(line.rstrip())

# Write the unified lines to findings.txt
with open(output_file, "w", encoding="utf-8") as f_out:
    for line in sorted(all_lines):
        f_out.write(line + "\n")

print(f"[✓] Union completed. {len(all_lines)} unique lines saved to {output_file}")
# Out:
# [✓] Union completed. 369 unique lines saved to ../tools_output/frizbee/findings.txt

# %%
import re
import json
from pathlib import Path

# Paths
original_dir = Path("../.github/workflows")
modified_dir = Path("../tools_output/frizbee/modified_workflows")
output_dir = Path("../tools_output/frizbee/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Pattern to detect pinned actions with hash and version comment
pattern = re.compile(r"uses:\s+([\w\-./]+)@([a-f0-9]{10,})\s+#\s*(\S+)", re.IGNORECASE)

# Gather workflow names directly from modified_workflows directory
modified_files = [p.name for p in modified_dir.glob("*.yml")] + [p.name for p in modified_dir.glob("*.yaml")]

saved = 0

for wf_name in modified_files:
    original_path = original_dir / wf_name
    modified_path = modified_dir / wf_name

    if not original_path.exists() or not modified_path.exists():
        print(f"[!] Skipped: {wf_name} (missing original or modified)")
        continue

    original_lines = original_path.read_text(encoding="utf-8").splitlines()
    modified_lines = modified_path.read_text(encoding="utf-8").splitlines()

    findings = []

    # Compare line by line
    for i, (orig, mod) in enumerate(zip(original_lines, modified_lines)):
        match = pattern.search(mod)
        if match:
            action, sha, tag = match.groups()
            expected_unpinned = f"{action}@{tag}"
            actual_pinned = f"{action}@{sha}"
            if expected_unpinned in orig:
                findings.append({
                    "rule": "unpinned-github-actions",
                    "original": expected_unpinned,
                    "pinned": actual_pinned,
                    "line": i + 1
                })

    if not findings:
        continue

    summary = {
        "total_findings": len(findings),
        "by_rule": {"unpinned-github-actions": len(findings)}
    }

    result = {
        "workflow": wf_name,
        "tool": "frizbee",
        "summary": summary,
        "findings": findings
    }

    with open(output_dir / f"{wf_name}.json", "w", encoding="utf-8") as out_f:
        json.dump(result, out_f, indent=2)
        saved += 1

print(f"Saved {saved} normalized workflow result files to {output_dir}")
# Out:
# Saved 384 normalized workflow result files to ../tools_output/frizbee/workflow_with_issues

# %% [markdown]
# SCHARF _______________________________________________________________________________

# %% [markdown]
# ./scharf audit . > tools_output/scharf/findings.txt

# %%
import re
import json
from pathlib import Path
from collections import defaultdict

# Input/output paths
input_file = Path("../tools_output/scharf/findings.txt")
output_dir = Path("../tools_output/scharf/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Regex to remove ANSI escape codes
ansi_escape = re.compile(r"\x1B\[[0-?]*[ -/]*[@-~]")

# Read and clean lines
lines = []
with open(input_file, "r", encoding="utf-8") as f:
    for raw in f:
        clean = ansi_escape.sub("", raw).strip()
        if clean:
            lines.append(clean)

# Initialize parsing
grouped = defaultdict(list)
current_workflow = None

# Go through each line
for line in lines:
    # Detect workflow line
    if line.endswith(".yml") or line.endswith(".yaml"):
        current_workflow = Path(line).name
        continue

    # Detect and parse issue line (new format)
    if current_workflow and "[Line" in line:
        match = re.search(r"\[Line (\d+), Col (\d+)\] (.+)", line)
        if match:
            line_num, col_num, message = match.groups()
            grouped[current_workflow].append({
                "line": int(line_num),
                "column": int(col_num),
                "message": message
            })
        else:
            print(f"[NO MATCH] {line}")

# Save per-workflow JSONs
for workflow_file, findings in grouped.items():
    output_data = {
        "workflow": workflow_file,
        "tool": "scharf",
        "summary": {
            "total_findings": len(findings),
            "by_rule": {
                "unpinned-github-actions": len(findings)
            }
        },
        "findings": findings
    }

    out_path = output_dir / f"{workflow_file}.json"
    with open(out_path, "w", encoding="utf-8") as f_out:
        json.dump(output_data, f_out, indent=2)

print(f"Saved {len(grouped)} workflow result files to {output_dir}")
# Out:
# Saved 402 workflow result files to ../tools_output/scharf/workflow_with_issues

# %% [markdown]
# PINNY ___________________________________________________________________________

# %% [markdown]
# ./pinny actions pin --dry-run > tools_output/pinny/findings.txt

# %%
import json
from pathlib import Path
from collections import defaultdict

# Paths
FINDINGS_FILE = Path("../tools_output/pinny/findings.txt")
WORKFLOWS_DIR = Path("../.github/workflows")
OUTPUT_DIR = Path("../tools_output/pinny/workflow_with_issues")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Step 1: Extract all unpinned actions from findings.txt
unresolved_refs = set()
with open(FINDINGS_FILE, "r", encoding="utf-8") as f:
    for line in f:
        if "Branch references are being used" in line or "No exact match found for ref" in line:
            parts = line.strip().split(":")
            if parts:
                action = parts[-1].strip().strip("`")
                if action:
                    unresolved_refs.add(action)

print(f"Found {len(unresolved_refs)} unpinned actions in findings.txt")

# Step 2: Search these refs in all workflow files
findings_by_file = defaultdict(list)

yml_files = list(WORKFLOWS_DIR.glob("*.yml")) + list(WORKFLOWS_DIR.glob("*.yaml"))
for yml_file in yml_files:
    with open(yml_file, "r", encoding="utf-8") as f:
        lines = f.readlines()

    for idx, line in enumerate(lines, 1):
        for ref in unresolved_refs:
            if ref in line:
                findings_by_file[yml_file.name].append({
                    "rule_id": "unpinned-github-actions",
                    "meta": {
                        "action": ref,
                        "line_snippet": line.strip(),
                        "line_number": idx
                    }
                })

# Step 3: Save per-workflow normalized output
for wf_file, findings in findings_by_file.items():
    summary = {
        "total_findings": len(findings),
        "by_rule": {"unpinned-github-actions": len(findings)}
    }

    result = {
        "workflow": wf_file,
        "tool": "pinny",
        "summary": summary,
        "findings": findings
    }

    with open(OUTPUT_DIR / f"{wf_file}.json", "w", encoding="utf-8") as f_out:
        json.dump(result, f_out, indent=2)

print(f"Saved {len(findings_by_file)} workflow result files to {OUTPUT_DIR}")
# Out:
# Found 18 unpinned actions in findings.txt
# Saved 30 workflow result files to ../tools_output/pinny/workflow_with_issues

# %% [markdown]
# ZIZMOR ________________________________________________________________________________

# %% [markdown]
# ./zizmor .github/workflows > tools_output/zizmor/findings.txt

# %%
import os
import subprocess
from pathlib import Path

WORKFLOW_DIR = "../.github/workflows"
ZIZMOR = "./../../tools/zizmor/zizmor"
RAW_DIR = Path("../tools_output/zizmor/raw_logs")
RAW_DIR.mkdir(parents=True, exist_ok=True)

for file in sorted(os.listdir(WORKFLOW_DIR)):
    if not file.endswith((".yml", ".yaml")):
        continue

    file_path = os.path.join(WORKFLOW_DIR, file)
    out_path = RAW_DIR / f"{file}.txt"

    try:
        with open(out_path, "w", encoding="utf-8") as out:
            subprocess.run(
                [ZIZMOR, file_path],
                stdout=out,
                stderr=subprocess.DEVNULL,
                text=True
            )
        print(f"✅ Saved findings: {file}")
    except Exception as e:
        print(f"❌ Failed on {file}: {e}")
# Out:
# ✅ Saved findings: AUTOMATIC1111_stable-diffusion-webui__on_pull_request.yaml
# ✅ Saved findings: AUTOMATIC1111_stable-diffusion-webui__run_tests.yaml
# ✅ Saved findings: AUTOMATIC1111_stable-diffusion-webui__warns_merge_master.yml
# ✅ Saved findings: Chalarangelo_30-seconds-of-code__deploy-production.yml
# ✅ Saved findings: Chalarangelo_30-seconds-of-code__label.yml
# ✅ Saved findings: Chalarangelo_30-seconds-of-code__stale.yml
# ✅ Saved findings: Chalarangelo_30-seconds-of-code__test.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__check-urls.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__comment-pr.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__detect-conflicting-prs.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__fpb-lint.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__issues-pinner.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__rtl-ltr-linter.yml
# ✅ Saved findings: EbookFoundation_free-programming-books__stale.yml
# ✅ Saved findings: Genymobile_scrcpy__release.yml
# ✅ Saved findings: IBM_sarama__apidiff.yml
# ✅ Saved findings: IBM_sarama__cache-cleanup.yml
# ✅ Saved findings: IBM_sarama__ci.yml
# ✅ Saved findings: IBM_sarama__codeql-analysis.yml
# ✅ Saved findings: IBM_sarama__dependency-review.yml
# ✅ Saved findings: IBM_sarama__fuzz.yml
# ✅ Saved findings: IBM_sarama__fvt-main.yml
# ✅ Saved findings: IBM_sarama__fvt-pr.yml
# ✅ Saved findings: IBM_sarama__fvt.yml
# ✅ Saved findings: IBM_sarama__i386.yml
# ✅ Saved findings: IBM_sarama__scorecard.yml
# ✅ Saved findings: IBM_sarama__stale.yml
# ✅ Saved findings: NVIDIA_cutlass__blossom-ci.yml
# ✅ Saved findings: NVIDIA_cutlass__labeler.yml
# ✅ Saved findings: NVIDIA_cutlass__new-issues-to-triage-projects.yml
# ✅ Saved findings: NVIDIA_cutlass__stale.yml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__basic-checks.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__ci.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__code_scanning.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__deploy-to-pages.yml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__e2e.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__golang.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__helm.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__image.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__publish-helm.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__release.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__stale.yaml
# ✅ Saved findings: NVIDIA_k8s-device-plugin__variables.yaml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-autogpt-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-autogpt-docker-cache-clean.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-autogpt-docker-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-autogpt-docker-release.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-autogpts-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-benchmark-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-benchmark_publish_package.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-forge-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-frontend-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__classic-python-checks.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__claude.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__codeql.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__platform-autgpt-deploy-prod.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__platform-autogpt-deploy-dev.yaml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__platform-backend-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__platform-dev-deploy-event-dispatcher.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__platform-frontend-ci.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__repo-close-stale-issues.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__repo-pr-enforce-base-branch.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__repo-pr-label.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__repo-stats.yml
# ✅ Saved findings: Significant-Gravitas_AutoGPT__repo-workflow-checker.yml
# ✅ Saved findings: Snailclimb_JavaGuide__test.yml
# ✅ Saved findings: TheAlgorithms_Python__build.yml
# ✅ Saved findings: TheAlgorithms_Python__directory_writer.yml
# ✅ Saved findings: TheAlgorithms_Python__project_euler.yml
# ✅ Saved findings: TheAlgorithms_Python__ruff.yml
# ✅ Saved findings: TheAlgorithms_Python__sphinx.yml
# ✅ Saved findings: airbnb_javascript__node-pretest.yml
# ✅ Saved findings: airbnb_javascript__node.yml
# ✅ Saved findings: airbnb_javascript__rebase.yml
# ✅ Saved findings: airbnb_javascript__require-allow-edits.yml
# ✅ Saved findings: alibaba_druid__ci.yaml
# ✅ Saved findings: alibaba_ice__canary.yml
# ✅ Saved findings: alibaba_ice__ci.yml
# ✅ Saved findings: alibaba_ice__coverage.yml
# ✅ Saved findings: alibaba_ice__release.yml
# ✅ Saved findings: alibaba_ice__version.yml
# ✅ Saved findings: alibaba_ice__website.yml
# ✅ Saved findings: alibaba_tengine__ci-arm64.yml
# ✅ Saved findings: alibaba_tengine__ci.yml
# ✅ Saved findings: alibaba_tengine__test-nginx-core.yml
# ✅ Saved findings: alibaba_tengine__test-ntls.yml
# ✅ Saved findings: alibaba_transmittable-thread-local__ci.yaml
# ✅ Saved findings: alibaba_transmittable-thread-local__strong_ci.yaml
# ✅ Saved findings: avelino_awesome-go__check-for-spammy-issues.yml
# ✅ Saved findings: avelino_awesome-go__pull-request-first-comment.yaml
# ✅ Saved findings: avelino_awesome-go__run-check.yaml
# ✅ Saved findings: avelino_awesome-go__site-deploy.yaml
# ✅ Saved findings: avelino_awesome-go__tests.yaml
# ✅ Saved findings: awslabs_amazon-ecr-credential-helper__build.yaml
# ✅ Saved findings: awslabs_amazon-ecr-credential-helper__check-links.yml
# ✅ Saved findings: awslabs_amazon-ecr-credential-helper__codeql.yml
# ✅ Saved findings: awslabs_amazon-ecr-credential-helper__new-pull-requests.yml
# ✅ Saved findings: awslabs_amazon-ecr-credential-helper__review-dependencies.yml
# ✅ Saved findings: axios_axios__ci.yml
# ✅ Saved findings: axios_axios__codeql-analysis.yml
# ✅ Saved findings: axios_axios__depsreview.yaml
# ✅ Saved findings: axios_axios__labeler.yml
# ✅ Saved findings: axios_axios__notify.yml
# ✅ Saved findings: axios_axios__npm-tag.yml
# ✅ Saved findings: axios_axios__pr-guard.yml
# ✅ Saved findings: axios_axios__pr.yml
# ✅ Saved findings: axios_axios__publish.yml
# ✅ Saved findings: axios_axios__sponsors.yml
# ✅ Saved findings: axios_axios__stale.yml
# ✅ Saved findings: d3_d3__deploy.yml
# ✅ Saved findings: d3_d3__test.yml
# ✅ Saved findings: denoland_deno__cargo_publish.yml
# ✅ Saved findings: denoland_deno__ci.yml
# ✅ Saved findings: denoland_deno__node_compat_test.yml
# ✅ Saved findings: denoland_deno__npm_publish.yml
# ✅ Saved findings: denoland_deno__post_publish.yml
# ✅ Saved findings: denoland_deno__promote_to_release.yml
# ✅ Saved findings: denoland_deno__start_release.yml
# ✅ Saved findings: denoland_deno__version_bump.yml
# ✅ Saved findings: denoland_deno__wpt_epoch.yml
# ✅ Saved findings: electron_electron__archaeologist-dig.yml
# ✅ Saved findings: electron_electron__audit-branch-ci.yml
# ✅ Saved findings: electron_electron__branch-created.yml
# ✅ Saved findings: electron_electron__build-git-cache.yml
# ✅ Saved findings: electron_electron__build.yml
# ✅ Saved findings: electron_electron__clean-src-cache.yml
# ✅ Saved findings: electron_electron__issue-commented.yml
# ✅ Saved findings: electron_electron__issue-labeled.yml
# ✅ Saved findings: electron_electron__issue-opened.yml
# ✅ Saved findings: electron_electron__issue-transferred.yml
# ✅ Saved findings: electron_electron__issue-unlabeled.yml
# ✅ Saved findings: electron_electron__linux-publish.yml
# ✅ Saved findings: electron_electron__macos-publish.yml
# ✅ Saved findings: electron_electron__non-maintainer-dependency-change.yml
# ✅ Saved findings: electron_electron__pipeline-electron-build-and-test-and-nan.yml
# ✅ Saved findings: electron_electron__pipeline-electron-build-and-test.yml
# ✅ Saved findings: electron_electron__pipeline-electron-docs-only.yml
# ✅ Saved findings: electron_electron__pipeline-electron-lint.yml
# ✅ Saved findings: electron_electron__pipeline-segment-electron-build.yml
# ✅ Saved findings: electron_electron__pipeline-segment-electron-gn-check.yml
# ✅ Saved findings: electron_electron__pipeline-segment-electron-test.yml
# ✅ Saved findings: electron_electron__pipeline-segment-node-nan-test.yml
# ✅ Saved findings: electron_electron__pull-request-labeled.yml
# ✅ Saved findings: electron_electron__scorecards.yml
# ✅ Saved findings: electron_electron__semantic.yml
# ✅ Saved findings: electron_electron__stable-prep-items.yml
# ✅ Saved findings: electron_electron__stale.yml
# ✅ Saved findings: electron_electron__windows-publish.yml
# ✅ Saved findings: excalidraw_excalidraw__autorelease-excalidraw.yml
# ✅ Saved findings: excalidraw_excalidraw__autorelease-preview.yml
# ✅ Saved findings: excalidraw_excalidraw__build-docker.yml
# ✅ Saved findings: excalidraw_excalidraw__cancel.yml
# ✅ Saved findings: excalidraw_excalidraw__lint.yml
# ✅ Saved findings: excalidraw_excalidraw__locales-coverage.yml
# ✅ Saved findings: excalidraw_excalidraw__publish-docker.yml
# ✅ Saved findings: excalidraw_excalidraw__semantic-pr-title.yml
# ✅ Saved findings: excalidraw_excalidraw__sentry-production.yml
# ✅ Saved findings: excalidraw_excalidraw__size-limit.yml
# ✅ Saved findings: excalidraw_excalidraw__test-coverage-pr.yml
# ✅ Saved findings: excalidraw_excalidraw__test.yml
# ✅ Saved findings: f_awesome-chatgpt-prompts__ai_bot.yml
# ✅ Saved findings: f_awesome-chatgpt-prompts__auto_commands.yml
# ✅ Saved findings: f_awesome-chatgpt-prompts__csv_linter.yml
# ✅ Saved findings: f_awesome-chatgpt-prompts__publish.yml
# ✅ Saved findings: facebook_create-react-app__build-and-test.yml
# ✅ Saved findings: facebook_create-react-app__e2e-base.yml
# ✅ Saved findings: facebook_create-react-app__lint.yml
# ✅ Saved findings: facebook_facebook-android-sdk__needs-attention.yml
# ✅ Saved findings: facebook_facebook-android-sdk__stale.yml
# ✅ Saved findings: facebook_facebook-ios-sdk__needs-attention.yml
# ✅ Saved findings: facebook_facebook-ios-sdk__stale.yml
# ✅ Saved findings: facebook_fbthrift__getdeps_linux.yml
# ✅ Saved findings: facebook_fbthrift__getdeps_mac.yml
# ✅ Saved findings: facebook_fbthrift__getdeps_windows.yml
# ✅ Saved findings: facebook_folly__TagIt.yml
# ✅ Saved findings: facebook_folly__getdeps_linux.yml
# ✅ Saved findings: facebook_folly__getdeps_mac.yml
# ✅ Saved findings: facebook_folly__getdeps_windows.yml
# ✅ Saved findings: facebook_folly__oss-build-and-test.yml
# ✅ Saved findings: facebook_hhvm__ubuntu.yml
# ✅ Saved findings: facebook_mcrouter__build.yml
# ✅ Saved findings: facebook_react-native__autorebase.yml
# ✅ Saved findings: facebook_react-native__bump-podfile-lock.yml
# ✅ Saved findings: facebook_react-native__cache-reaper.yml
# ✅ Saved findings: facebook_react-native__check-for-reproducer.yml
# ✅ Saved findings: facebook_react-native__check-nightly.yml
# ✅ Saved findings: facebook_react-native__close-pr.yml
# ✅ Saved findings: facebook_react-native__create-draft-release.yml
# ✅ Saved findings: facebook_react-native__create-release.yml
# ✅ Saved findings: facebook_react-native__danger-pr.yml
# ✅ Saved findings: facebook_react-native__generate-changelog.yml
# ✅ Saved findings: facebook_react-native__monitor-new-issues.yml
# ✅ Saved findings: facebook_react-native__needs-attention.yml
# ✅ Saved findings: facebook_react-native__nightly.yml
# ✅ Saved findings: facebook_react-native__on-issue-labeled.yml
# ✅ Saved findings: facebook_react-native__prebuild-ios-core.yml
# ✅ Saved findings: facebook_react-native__prebuild-ios-dependencies.yml
# ✅ Saved findings: facebook_react-native__publish-bumped-packages.yml
# ✅ Saved findings: facebook_react-native__publish-release.yml
# ✅ Saved findings: facebook_react-native__retry-workflow.yml
# ✅ Saved findings: facebook_react-native__stale-bot.yml
# ✅ Saved findings: facebook_react-native__test-all.yml
# ✅ Saved findings: facebook_react-native__test-libraries-on-nightlies.yml
# ✅ Saved findings: facebook_react__compiler_discord_notify.yml
# ✅ Saved findings: facebook_react__compiler_playground.yml
# ✅ Saved findings: facebook_react__compiler_prereleases.yml
# ✅ Saved findings: facebook_react__compiler_prereleases_manual.yml
# ✅ Saved findings: facebook_react__compiler_prereleases_nightly.yml
# ✅ Saved findings: facebook_react__compiler_typescript.yml
# ✅ Saved findings: facebook_react__devtools_regression_tests.yml
# ✅ Saved findings: facebook_react__runtime_build_and_test.yml
# ✅ Saved findings: facebook_react__runtime_commit_artifacts.yml
# ✅ Saved findings: facebook_react__runtime_discord_notify.yml
# ✅ Saved findings: facebook_react__runtime_eslint_plugin_e2e.yml
# ✅ Saved findings: facebook_react__runtime_fuzz_tests.yml
# ✅ Saved findings: facebook_react__runtime_prereleases.yml
# ✅ Saved findings: facebook_react__runtime_prereleases_manual.yml
# ✅ Saved findings: facebook_react__runtime_prereleases_nightly.yml
# ✅ Saved findings: facebook_react__runtime_releases_from_npm_manual.yml
# ✅ Saved findings: facebook_react__shared_check_maintainer.yml
# ✅ Saved findings: facebook_react__shared_cleanup_merged_branch_caches.yml
# ✅ Saved findings: facebook_react__shared_cleanup_stale_branch_caches.yml
# ✅ Saved findings: facebook_react__shared_close_direct_sync_branch_prs.yml
# ✅ Saved findings: facebook_react__shared_label_core_team_prs.yml
# ✅ Saved findings: facebook_react__shared_lint.yml
# ✅ Saved findings: facebook_react__shared_stale.yml
# ✅ Saved findings: facebook_rocksdb__benchmark-linux.yml
# ✅ Saved findings: facebook_rocksdb__nightly-candidate.yml
# ✅ Saved findings: facebook_rocksdb__nightly.yml
# ✅ Saved findings: facebook_rocksdb__pr-jobs-candidate.yml
# ✅ Saved findings: facebook_rocksdb__pr-jobs.yml
# ✅ Saved findings: facebook_watchman__getdeps_linux.yml
# ✅ Saved findings: facebook_watchman__getdeps_mac.yml
# ✅ Saved findings: facebook_watchman__getdeps_windows.yml
# ✅ Saved findings: facebook_watchman__package.yml
# ✅ Saved findings: facebook_watchman__release.yml
# ✅ Saved findings: flutter_flutter__content-aware-hash.yml
# ✅ Saved findings: flutter_flutter__coverage.yml
# ✅ Saved findings: flutter_flutter__easy-cp.yml
# ✅ Saved findings: flutter_flutter__files-changed.yml
# ✅ Saved findings: flutter_flutter__labeler.yml
# ✅ Saved findings: flutter_flutter__lock.yaml
# ✅ Saved findings: flutter_flutter__merge-changelog.yml
# ✅ Saved findings: flutter_flutter__mirror.yml
# ✅ Saved findings: flutter_flutter__no-response.yaml
# ✅ Saved findings: flutter_flutter__tool-test-general.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__crowdin-download.client-ui.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__crowdin-upload.client-ui.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__crowdin-upload.curriculum.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__curriculum-i18n-submodule.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__deploy-api.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__deploy-client.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__docker-docr-cleanup.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__docker-docr.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__docker-ghcr.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__e2e-playwright.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__e2e-third-party.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__github-autoclose.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__github-labeler.yaml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__github-no-i18n-via-prs.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__github-no-web-commits.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__github-spam.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__i18n-validate-builds.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__i18n-validate-prs.yml
# ✅ Saved findings: freeCodeCamp_freeCodeCamp__node.js-tests.yml
# ✅ Saved findings: github_gitignore__stale.yml
# ✅ Saved findings: goldbergyoni_nodebestpractices__automerge-prs.yml
# ✅ Saved findings: goldbergyoni_nodebestpractices__lint-and-generate-html-from-markdown.yml
# ✅ Saved findings: goldbergyoni_nodebestpractices__update-date-in-last-update-badge.yml
# ✅ Saved findings: google_auto__ci.yml
# ✅ Saved findings: google_blockly__appengine_deploy.yml
# ✅ Saved findings: google_blockly__assign_reviewers.yml
# ✅ Saved findings: google_blockly__browser_test.yml
# ✅ Saved findings: google_blockly__build.yml
# ✅ Saved findings: google_blockly__conventional-label.yml
# ✅ Saved findings: google_blockly__develop_freeze.yml
# ✅ Saved findings: google_blockly__keyboard_plugin_test.yml
# ✅ Saved findings: google_blockly__tag_module_cleanup.yml
# ✅ Saved findings: google_blockly__welcome_new_contributors.yml
# ✅ Saved findings: google_dagger__ci.yml
# ✅ Saved findings: google_dagger__release.yml
# ✅ Saved findings: google_go-github__linter.yml
# ✅ Saved findings: google_go-github__tests.yml
# ✅ Saved findings: google_go-querystring__linter.yml
# ✅ Saved findings: google_go-querystring__tests.yml
# ✅ Saved findings: google_grr__build.yml
# ✅ Saved findings: google_grr__publish-pypi.yml
# ✅ Saved findings: google_jimfs__ci.yml
# ✅ Saved findings: google_truth__ci.yml
# ✅ Saved findings: huggingface_transformers__add-model-like.yml
# ✅ Saved findings: huggingface_transformers__assign-reviewers.yml
# ✅ Saved findings: huggingface_transformers__benchmark.yml
# ✅ Saved findings: huggingface_transformers__build-ci-docker-images.yml
# ✅ Saved findings: huggingface_transformers__build-docker-images.yml
# ✅ Saved findings: huggingface_transformers__build-nightly-ci-docker-images.yml
# ✅ Saved findings: huggingface_transformers__build-past-ci-docker-images.yml
# ✅ Saved findings: huggingface_transformers__build_documentation.yml
# ✅ Saved findings: huggingface_transformers__build_pr_documentation.yml
# ✅ Saved findings: huggingface_transformers__check_failed_tests.yml
# ✅ Saved findings: huggingface_transformers__check_tiny_models.yml
# ✅ Saved findings: huggingface_transformers__doctest_job.yml
# ✅ Saved findings: huggingface_transformers__doctests.yml
# ✅ Saved findings: huggingface_transformers__model_jobs.yml
# ✅ Saved findings: huggingface_transformers__model_jobs_intel_gaudi.yml
# ✅ Saved findings: huggingface_transformers__new_model_pr_merged_notification.yml
# ✅ Saved findings: huggingface_transformers__pr-style-bot.yml
# ✅ Saved findings: huggingface_transformers__push-important-models.yml
# ✅ Saved findings: huggingface_transformers__release-conda.yml
# ✅ Saved findings: huggingface_transformers__self-comment-ci.yml
# ✅ Saved findings: huggingface_transformers__self-nightly-caller.yml
# ✅ Saved findings: huggingface_transformers__self-nightly-past-ci-caller.yml
# ✅ Saved findings: huggingface_transformers__self-past-caller.yml
# ✅ Saved findings: huggingface_transformers__self-push-amd-mi210-caller.yml
# ✅ Saved findings: huggingface_transformers__self-push-amd-mi250-caller.yml
# ✅ Saved findings: huggingface_transformers__self-push-amd-mi300-caller.yml
# ✅ Saved findings: huggingface_transformers__self-push-amd.yml
# ✅ Saved findings: huggingface_transformers__self-push-caller.yml
# ✅ Saved findings: huggingface_transformers__self-push.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-amd-caller.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-amd-mi250-caller.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-amd-mi300-caller.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-caller.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-intel-gaudi.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled-intel-gaudi3-caller.yml
# ✅ Saved findings: huggingface_transformers__self-scheduled.yml
# ✅ Saved findings: huggingface_transformers__slack-report.yml
# ✅ Saved findings: huggingface_transformers__ssh-runner.yml
# ✅ Saved findings: huggingface_transformers__stale.yml
# ✅ Saved findings: huggingface_transformers__trufflehog.yml
# ✅ Saved findings: huggingface_transformers__update_metdata.yml
# ✅ Saved findings: huggingface_transformers__upload_pr_documentation.yml
# ✅ Saved findings: jwasham_coding-interview-university__links_checker.yml
# ✅ Saved findings: krahets_hello-algo__c.yml
# ✅ Saved findings: krahets_hello-algo__cpp.yml
# ✅ Saved findings: krahets_hello-algo__dart.yml
# ✅ Saved findings: krahets_hello-algo__dotnet.yml
# ✅ Saved findings: krahets_hello-algo__go.yml
# ✅ Saved findings: krahets_hello-algo__java.yml
# ✅ Saved findings: krahets_hello-algo__javascript.yml
# ✅ Saved findings: krahets_hello-algo__kotlin.yml
# ✅ Saved findings: krahets_hello-algo__python.yml
# ✅ Saved findings: krahets_hello-algo__ruby.yml
# ✅ Saved findings: krahets_hello-algo__rust.yml
# ✅ Saved findings: krahets_hello-algo__swift.yml
# ✅ Saved findings: krahets_hello-algo__typescript.yml
# ✅ Saved findings: langchain-ai_langchain___compile_integration_test.yml
# ✅ Saved findings: langchain-ai_langchain___integration_test.yml
# ✅ Saved findings: langchain-ai_langchain___lint.yml
# ✅ Saved findings: langchain-ai_langchain___release.yml
# ✅ Saved findings: langchain-ai_langchain___test.yml
# ✅ Saved findings: langchain-ai_langchain___test_doc_imports.yml
# ✅ Saved findings: langchain-ai_langchain___test_pydantic.yml
# ✅ Saved findings: langchain-ai_langchain___test_release.yml
# ✅ Saved findings: langchain-ai_langchain__api_doc_build.yml
# ✅ Saved findings: langchain-ai_langchain__check-broken-links.yml
# ✅ Saved findings: langchain-ai_langchain__check_core_versions.yml
# ✅ Saved findings: langchain-ai_langchain__check_diffs.yml
# ✅ Saved findings: langchain-ai_langchain__check_new_docs.yml
# ✅ Saved findings: langchain-ai_langchain__codespell.yml
# ✅ Saved findings: langchain-ai_langchain__codspeed.yml
# ✅ Saved findings: langchain-ai_langchain__people.yml
# ✅ Saved findings: langchain-ai_langchain__run_notebooks.yml
# ✅ Saved findings: langchain-ai_langchain__scheduled_test.yml
# ✅ Saved findings: langgenius_dify__api-tests.yml
# ✅ Saved findings: langgenius_dify__build-push.yml
# ✅ Saved findings: langgenius_dify__db-migration-test.yml
# ✅ Saved findings: langgenius_dify__deploy-dev.yml
# ✅ Saved findings: langgenius_dify__deploy-enterprise.yml
# ✅ Saved findings: langgenius_dify__deploy-rag-dev.yml
# ✅ Saved findings: langgenius_dify__docker-build.yml
# ✅ Saved findings: langgenius_dify__stale.yml
# ✅ Saved findings: langgenius_dify__style.yml
# ✅ Saved findings: langgenius_dify__tool-test-sdks.yaml
# ✅ Saved findings: langgenius_dify__translate-i18n-base-on-english.yml
# ✅ Saved findings: langgenius_dify__vdb-tests.yml
# ✅ Saved findings: langgenius_dify__web-tests.yml
# ✅ Saved findings: microsoft_PowerToys__dependency-review.yml
# ✅ Saved findings: microsoft_PowerToys__msstore-submissions.yml
# ✅ Saved findings: microsoft_PowerToys__package-submissions.yml
# ✅ Saved findings: microsoft_PowerToys__spelling2.yml
# ✅ Saved findings: microsoft_TypeScript__accept-baselines-fix-lints.yaml
# ✅ Saved findings: microsoft_TypeScript__ci.yml
# ✅ Saved findings: microsoft_TypeScript__close-issues.yml
# ✅ Saved findings: microsoft_TypeScript__codeql.yml
# ✅ Saved findings: microsoft_TypeScript__copilot-setup-steps.yml
# ✅ Saved findings: microsoft_TypeScript__create-cherry-pick-pr.yml
# ✅ Saved findings: microsoft_TypeScript__error-deltas-watchdog.yaml
# ✅ Saved findings: microsoft_TypeScript__insiders.yaml
# ✅ Saved findings: microsoft_TypeScript__lkg.yml
# ✅ Saved findings: microsoft_TypeScript__new-release-branch.yaml
# ✅ Saved findings: microsoft_TypeScript__nightly.yaml
# ✅ Saved findings: microsoft_TypeScript__pr-modified-files.yml
# ✅ Saved findings: microsoft_TypeScript__release-branch-artifact.yaml
# ✅ Saved findings: microsoft_TypeScript__scorecard.yml
# ✅ Saved findings: microsoft_TypeScript__set-version.yaml
# ✅ Saved findings: microsoft_TypeScript__sync-branch.yaml
# ✅ Saved findings: microsoft_TypeScript__sync-wiki.yml
# ✅ Saved findings: microsoft_TypeScript__twoslash-repros.yaml
# ✅ Saved findings: microsoft_TypeScript__update-package-lock.yaml
# ✅ Saved findings: microsoft_terminal__addToProject.yml
# ✅ Saved findings: microsoft_terminal__spelling2.yml
# ✅ Saved findings: microsoft_terminal__winget.yml
# ✅ Saved findings: microsoft_vscode__basic.yml
# ✅ Saved findings: microsoft_vscode__ci.yml
# ✅ Saved findings: microsoft_vscode__monaco-editor.yml
# ✅ Saved findings: microsoft_vscode__no-package-lock-changes.yml
# ✅ Saved findings: microsoft_vscode__no-yarn-lock-changes.yml
# ✅ Saved findings: microsoft_vscode__telemetry.yml
# ✅ Saved findings: mrdoob_three.js__ci.yml
# ✅ Saved findings: mrdoob_three.js__codeql-code-scanning.yml
# ✅ Saved findings: mrdoob_three.js__read-size.yml
# ✅ Saved findings: mrdoob_three.js__report-size.yml
# ✅ Saved findings: n8n-io_n8n__benchmark-destroy-nightly.yml
# ✅ Saved findings: n8n-io_n8n__benchmark-nightly.yml
# ✅ Saved findings: n8n-io_n8n__check-documentation-urls.yml
# ✅ Saved findings: n8n-io_n8n__check-pr-title.yml
# ✅ Saved findings: n8n-io_n8n__check-run-eligibility.yml
# ✅ Saved findings: n8n-io_n8n__chromatic.yml
# ✅ Saved findings: n8n-io_n8n__ci-master.yml
# ✅ Saved findings: n8n-io_n8n__ci-postgres-mysql.yml
# ✅ Saved findings: n8n-io_n8n__ci-pull-requests.yml
# ✅ Saved findings: n8n-io_n8n__docker-base-image.yml
# ✅ Saved findings: n8n-io_n8n__docker-build-push.yml
# ✅ Saved findings: n8n-io_n8n__docker-images-benchmark.yml
# ✅ Saved findings: n8n-io_n8n__e2e-flaky.yml
# ✅ Saved findings: n8n-io_n8n__e2e-reusable.yml
# ✅ Saved findings: n8n-io_n8n__e2e-tests-pr.yml
# ✅ Saved findings: n8n-io_n8n__e2e-tests.yml
# ✅ Saved findings: n8n-io_n8n__linting-reusable.yml
# ✅ Saved findings: n8n-io_n8n__notify-pr-status.yml
# ✅ Saved findings: n8n-io_n8n__release-create-pr.yml
# ✅ Saved findings: n8n-io_n8n__release-publish.yml
# ✅ Saved findings: n8n-io_n8n__release-push-to-channel.yml
# ✅ Saved findings: n8n-io_n8n__security-trivy-scan-callable.yml
# ✅ Saved findings: n8n-io_n8n__test-workflows-callable.yml
# ✅ Saved findings: n8n-io_n8n__test-workflows-nightly.yml
# ✅ Saved findings: n8n-io_n8n__test-workflows-pr-approved.yml
# ✅ Saved findings: n8n-io_n8n__test-workflows-pr-comment.yml
# ✅ Saved findings: n8n-io_n8n__units-tests-reusable.yml
# ✅ Saved findings: nodejs_node__auto-start-ci.yml
# ✅ Saved findings: nodejs_node__build-tarball.yml
# ✅ Saved findings: nodejs_node__close-stale-feature-requests.yml
# ✅ Saved findings: nodejs_node__close-stale-pull-requests.yml
# ✅ Saved findings: nodejs_node__close-stalled.yml
# ✅ Saved findings: nodejs_node__codeql.yml
# ✅ Saved findings: nodejs_node__comment-labeled.yml
# ✅ Saved findings: nodejs_node__commit-lint.yml
# ✅ Saved findings: nodejs_node__commit-queue.yml
# ✅ Saved findings: nodejs_node__coverage-linux-without-intl.yml
# ✅ Saved findings: nodejs_node__coverage-linux.yml
# ✅ Saved findings: nodejs_node__coverage-windows.yml
# ✅ Saved findings: nodejs_node__create-release-proposal.yml
# ✅ Saved findings: nodejs_node__daily-wpt-fyi.yml
# ✅ Saved findings: nodejs_node__daily.yml
# ✅ Saved findings: nodejs_node__doc.yml
# ✅ Saved findings: nodejs_node__find-inactive-collaborators.yml
# ✅ Saved findings: nodejs_node__find-inactive-tsc.yml
# ✅ Saved findings: nodejs_node__label-flaky-test-issue.yml
# ✅ Saved findings: nodejs_node__label-pr.yml
# ✅ Saved findings: nodejs_node__license-builder.yml
# ✅ Saved findings: nodejs_node__lint-release-proposal.yml
# ✅ Saved findings: nodejs_node__linters.yml
# ✅ Saved findings: nodejs_node__major-release.yml
# ✅ Saved findings: nodejs_node__notify-on-push.yml
# ✅ Saved findings: nodejs_node__notify-on-review-wanted.yml
# ✅ Saved findings: nodejs_node__scorecard.yml
# ✅ Saved findings: nodejs_node__test-internet.yml
# ✅ Saved findings: nodejs_node__test-linux.yml
# ✅ Saved findings: nodejs_node__test-macos.yml
# ✅ Saved findings: nodejs_node__timezone-update.yml
# ✅ Saved findings: nodejs_node__tools.yml
# ✅ Saved findings: nodejs_node__update-openssl.yml
# ✅ Saved findings: nodejs_node__update-release-links.yml
# ✅ Saved findings: nodejs_node__update-v8.yml
# ✅ Saved findings: nodejs_node__update-wpt.yml
# ✅ Saved findings: ohmyzsh_ohmyzsh__dependencies.yml
# ✅ Saved findings: ohmyzsh_ohmyzsh__installer.yml
# ✅ Saved findings: ohmyzsh_ohmyzsh__main.yml
# ✅ Saved findings: ohmyzsh_ohmyzsh__project.yml
# ✅ Saved findings: ollama_ollama__latest.yaml
# ✅ Saved findings: ollama_ollama__release.yaml
# ✅ Saved findings: ollama_ollama__test.yaml
# ✅ Saved findings: open-webui_open-webui__build-release.yml
# ✅ Saved findings: open-webui_open-webui__deploy-to-hf-spaces.yml
# ✅ Saved findings: open-webui_open-webui__docker-build.yaml
# ✅ Saved findings: open-webui_open-webui__format-backend.yaml
# ✅ Saved findings: open-webui_open-webui__format-build-frontend.yaml
# ✅ Saved findings: open-webui_open-webui__release-pypi.yml
# ✅ Saved findings: oracle_docker-images__build-and-push-dev-images.yml
# ✅ Saved findings: oracle_docker-images__build-and-push-instantclient-images.yml
# ✅ Saved findings: oracle_docker-images__build-and-push-nosql-image.yml
# ✅ Saved findings: oracle_docker-images__build-and-push-nosql-sec-image.yml
# ✅ Saved findings: oracle_docker-images__build-and-push-oci-cli-image.yml
# ✅ Saved findings: oracle_docker-images__super-linter.yml
# ✅ Saved findings: oracle_graal__cdt-inspect.yml
# ✅ Saved findings: oracle_graal__main.yml
# ✅ Saved findings: oracle_graal__micronaut.yml
# ✅ Saved findings: oracle_graal__ni-layers.yml
# ✅ Saved findings: oracle_graal__quarkus.yml
# ✅ Saved findings: oracle_graal__reachability-metadata.yml
# ✅ Saved findings: oracle_graal__spring.yml
# ✅ Saved findings: oracle_opengrok__apiary.yml
# ✅ Saved findings: oracle_opengrok__build.yml
# ✅ Saved findings: oracle_opengrok__codeql-analysis.yml
# ✅ Saved findings: oracle_opengrok__docker.yml
# ✅ Saved findings: oracle_opengrok__javadoc.yml
# ✅ Saved findings: oracle_opengrok__release.yml
# ✅ Saved findings: oracle_truffleruby__ci.yml
# ✅ Saved findings: oracle_truffleruby__prism.yml
# ✅ Saved findings: ossu_computer-science__delete-empty-issues.yml
# ✅ Saved findings: public-apis_public-apis__test_of_push_and_pull.yml
# ✅ Saved findings: public-apis_public-apis__test_of_validate_package.yml
# ✅ Saved findings: public-apis_public-apis__validate_links.yml
# ✅ Saved findings: rust-lang_rust__ci.yml
# ✅ Saved findings: rust-lang_rust__dependencies.yml
# ✅ Saved findings: rust-lang_rust__ghcr.yml
# ✅ Saved findings: rust-lang_rust__post-merge.yml
# ✅ Saved findings: sindresorhus_awesome__main.yml
# ✅ Saved findings: tensorflow_tensorflow__arm-cd.yml
# ✅ Saved findings: tensorflow_tensorflow__arm-ci-extended-cpp.yml
# ✅ Saved findings: tensorflow_tensorflow__arm-ci-extended.yml
# ✅ Saved findings: tensorflow_tensorflow__arm-ci.yml
# ✅ Saved findings: tensorflow_tensorflow__cffconvert.yml
# ✅ Saved findings: tensorflow_tensorflow__issue-on-pr-rollback.yml
# ✅ Saved findings: tensorflow_tensorflow__osv-scanner-scheduled.yml
# ✅ Saved findings: tensorflow_tensorflow__pylint-presubmit.yml
# ✅ Saved findings: tensorflow_tensorflow__release-branch-cherrypick.yml
# ✅ Saved findings: tensorflow_tensorflow__scorecards-analysis.yml
# ✅ Saved findings: tensorflow_tensorflow__stale-issues.yml
# ✅ Saved findings: tensorflow_tensorflow__update-nightly.yml
# ✅ Saved findings: tensorflow_tensorflow__update-rbe.yml
# ✅ Saved findings: trekhleb_javascript-algorithms__CI.yml
# ✅ Saved findings: twbs_bootstrap__browserstack.yml
# ✅ Saved findings: twbs_bootstrap__bundlewatch.yml
# ✅ Saved findings: twbs_bootstrap__calibreapp-image-actions.yml
# ✅ Saved findings: twbs_bootstrap__codeql.yml
# ✅ Saved findings: twbs_bootstrap__cspell.yml
# ✅ Saved findings: twbs_bootstrap__css.yml
# ✅ Saved findings: twbs_bootstrap__docs.yml
# ✅ Saved findings: twbs_bootstrap__issue-close-require.yml
# ✅ Saved findings: twbs_bootstrap__issue-labeled.yml
# ✅ Saved findings: twbs_bootstrap__js.yml
# ✅ Saved findings: twbs_bootstrap__lint.yml
# ✅ Saved findings: twbs_bootstrap__node-sass.yml
# ✅ Saved findings: twbs_bootstrap__release-notes.yml
# ✅ Saved findings: vercel_next.js__build_and_deploy.yml
# ✅ Saved findings: vercel_next.js__build_and_test.yml
# ✅ Saved findings: vercel_next.js__build_reusable.yml
# ✅ Saved findings: vercel_next.js__cancel.yml
# ✅ Saved findings: vercel_next.js__code_freeze.yml
# ✅ Saved findings: vercel_next.js__force_merge_canary_release_pr.yml
# ✅ Saved findings: vercel_next.js__graphite_ci_optimizer.yml
# ✅ Saved findings: vercel_next.js__integration_tests_reusable.yml
# ✅ Saved findings: vercel_next.js__issue_bankrupt.yml
# ✅ Saved findings: vercel_next.js__issue_lock.yml
# ✅ Saved findings: vercel_next.js__issue_stale.yml
# ✅ Saved findings: vercel_next.js__issue_version.yml
# ✅ Saved findings: vercel_next.js__issue_wrong_template.yml
# ✅ Saved findings: vercel_next.js__notify_release.yml
# ✅ Saved findings: vercel_next.js__popular.yml
# ✅ Saved findings: vercel_next.js__pull_request_stats.yml
# ✅ Saved findings: vercel_next.js__retry_deploy_test.yml
# ✅ Saved findings: vercel_next.js__retry_test.yml
# ✅ Saved findings: vercel_next.js__rspack-nextjs-build-integration-tests.yml
# ✅ Saved findings: vercel_next.js__rspack-nextjs-dev-integration-tests.yml
# ✅ Saved findings: vercel_next.js__rspack-update-tests-manifest.yml
# ✅ Saved findings: vercel_next.js__setup-nextjs-build.yml
# ✅ Saved findings: vercel_next.js__test-turbopack-rust-bench-test.yml
# ✅ Saved findings: vercel_next.js__test_e2e_deploy_release.yml
# ✅ Saved findings: vercel_next.js__test_examples.yml
# ✅ Saved findings: vercel_next.js__triage.yml
# ✅ Saved findings: vercel_next.js__triage_with_ai.yml
# ✅ Saved findings: vercel_next.js__trigger_release.yml
# ✅ Saved findings: vercel_next.js__trigger_release_new.yml
# ✅ Saved findings: vercel_next.js__turbopack-benchmark.yml
# ✅ Saved findings: vercel_next.js__turbopack-nextjs-build-integration-tests.yml
# ✅ Saved findings: vercel_next.js__turbopack-nextjs-dev-integration-tests.yml
# ✅ Saved findings: vercel_next.js__turbopack-update-tests-manifest.yml
# ✅ Saved findings: vercel_next.js__update_fonts_data.yml
# ✅ Saved findings: vercel_next.js__update_react.yml
# ✅ Saved findings: vercel_next.js__upload-tests-manifest.yml
# ✅ Saved findings: vuejs_vue__ci.yml
# ✅ Saved findings: vuejs_vue__release-tag.yml
# ✅ Saved findings: yangshun_tech-interview-handbook__lint.yml
# ✅ Saved findings: yangshun_tech-interview-handbook__tsc.yml
# ✅ Saved findings: yt-dlp_yt-dlp__build.yml
# ✅ Saved findings: yt-dlp_yt-dlp__codeql.yml
# ✅ Saved findings: yt-dlp_yt-dlp__core.yml
# ✅ Saved findings: yt-dlp_yt-dlp__download.yml
# ✅ Saved findings: yt-dlp_yt-dlp__issue-lockdown.yml
# ✅ Saved findings: yt-dlp_yt-dlp__quick-test.yml
# ✅ Saved findings: yt-dlp_yt-dlp__release-master.yml
# ✅ Saved findings: yt-dlp_yt-dlp__release-nightly.yml
# ✅ Saved findings: yt-dlp_yt-dlp__release.yml
# ✅ Saved findings: yt-dlp_yt-dlp__sanitize-comment.yml
# ✅ Saved findings: ytdl-org_youtube-dl__ci.yml

# %%
import re
import json
from pathlib import Path

# Paths
input_dir = Path("../tools_output/zizmor/raw_logs")
output_dir = Path("../tools_output/zizmor/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Regex patterns
ansi_escape = re.compile(r"\x1B\[[0-?]*[ -/]*[@-~]")  # standard ANSI colors
osc8_link = re.compile(r"\x1b]8;;[^\x1b]*\x1b\\(.*?)\x1b]8;;\x1b\\")  # hyperlinks
finding_pattern = re.compile(r"(info|warning|error)\[(.+?)\]: (.+)")
# FIXED: allow optional "../" before .github
location_pattern = re.compile(r"-->\s+(?:\.\./)?\.github/workflows/(.+?):(\d+):(\d+)")
note_pattern = re.compile(r"= note: (.+)", re.IGNORECASE)

saved_files = 0

for input_file in input_dir.glob("*.txt"):
    findings = []
    current = {}
    workflow_file = input_file.stem

    with open(input_file, encoding="utf-8") as f:
        raw_lines = f.readlines()

    # Strip ANSI & hyperlinks
    clean_lines = []
    for line in raw_lines:
        line = ansi_escape.sub("", line)
        line = osc8_link.sub(r"\1", line)
        clean_lines.append(line.strip())

    if any("No findings to report" in line for line in clean_lines):
        continue

    for line in clean_lines:
        if not line:
            continue

        m = finding_pattern.match(line)
        if m:
            if current.get("rule_id"):
                findings.append(current)

            level, rule_id, message = m.groups()
            rule_id = osc8_link.sub(r"\1", rule_id)
            current = {
                "rule_id": rule_id.strip(),
                "level": level,
                "message": message.strip(),
                "workflow": workflow_file,
                "line": None,
                "column": None,
                "note": None
            }
            continue

        m = location_pattern.match(line)
        if m:
            _, line_num, col_num = m.groups()
            current["line"] = int(line_num)
            current["column"] = int(col_num)
            continue

        m = note_pattern.match(line)
        if m:
            current["note"] = m.group(1).strip()
            continue

    if current.get("rule_id"):
        findings.append(current)

    if not findings:
        continue

    rule_summary = {}
    for f in findings:
        rule_summary[f["rule_id"]] = rule_summary.get(f["rule_id"], 0) + 1

    result = {
        "workflow": workflow_file,
        "tool": "zizmor",
        "summary": {
            "total_findings": len(findings),
            "by_rule": rule_summary
        },
        "findings": findings
    }

    out_path = output_dir / f"{workflow_file}.json"
    with open(out_path, "w", encoding="utf-8") as out:
        json.dump(result, out, indent=2)

    saved_files += 1
    print(f"✅ {workflow_file} → {len(findings)} findings")

print(f"\n✅ Parsed {saved_files} workflow result files to {output_dir}")
# Out:
# ✅ huggingface_transformers__self-comment-ci.yml → 36 findings
# ✅ open-webui_open-webui__release-pypi.yml → 2 findings
# ✅ excalidraw_excalidraw__sentry-production.yml → 2 findings
# ✅ oracle_opengrok__apiary.yml → 2 findings
# ✅ alibaba_ice__release.yml → 4 findings
# ✅ f_awesome-chatgpt-prompts__auto_commands.yml → 1 findings
# ✅ axios_axios__pr-guard.yml → 2 findings
# ✅ nodejs_node__comment-labeled.yml → 1 findings
# ✅ oracle_graal__micronaut.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__classic-autogpt-docker-ci.yml → 10 findings
# ✅ awslabs_amazon-ecr-credential-helper__build.yaml → 8 findings
# ✅ facebook_mcrouter__build.yml → 2 findings
# ✅ n8n-io_n8n__benchmark-nightly.yml → 1 findings
# ✅ ossu_computer-science__delete-empty-issues.yml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__github-no-web-commits.yml → 2 findings
# ✅ oracle_graal__main.yml → 4 findings
# ✅ facebook_react-native__create-release.yml → 4 findings
# ✅ vercel_next.js__rspack-update-tests-manifest.yml → 5 findings
# ✅ langchain-ai_langchain___release.yml → 15 findings
# ✅ denoland_deno__cargo_publish.yml → 6 findings
# ✅ open-webui_open-webui__docker-build.yaml → 53 findings
# ✅ vercel_next.js__triage_with_ai.yml → 2 findings
# ✅ vercel_next.js__upload-tests-manifest.yml → 2 findings
# ✅ Chalarangelo_30-seconds-of-code__deploy-production.yml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__crowdin-download.client-ui.yml → 16 findings
# ✅ google_blockly__tag_module_cleanup.yml → 2 findings
# ✅ vercel_next.js__triage.yml → 1 findings
# ✅ facebook_watchman__release.yml → 39 findings
# ✅ goldbergyoni_nodebestpractices__update-date-in-last-update-badge.yml → 3 findings
# ✅ langgenius_dify__style.yml → 8 findings
# ✅ denoland_deno__node_compat_test.yml → 11 findings
# ✅ vercel_next.js__turbopack-update-tests-manifest.yml → 5 findings
# ✅ n8n-io_n8n__release-publish.yml → 9 findings
# ✅ facebook_react__shared_label_core_team_prs.yml → 1 findings
# ✅ vercel_next.js__build_reusable.yml → 11 findings
# ✅ n8n-io_n8n__docker-base-image.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__classic-autogpt-docker-release.yml → 5 findings
# ✅ awslabs_amazon-ecr-credential-helper__review-dependencies.yml → 1 findings
# ✅ facebook_hhvm__ubuntu.yml → 2 findings
# ✅ excalidraw_excalidraw__build-docker.yml → 2 findings
# ✅ nodejs_node__codeql.yml → 1 findings
# ✅ facebook_rocksdb__pr-jobs-candidate.yml → 2 findings
# ✅ facebook_react__runtime_fuzz_tests.yml → 1 findings
# ✅ ytdl-org_youtube-dl__ci.yml → 10 findings
# ✅ microsoft_PowerToys__msstore-submissions.yml → 5 findings
# ✅ oracle_graal__cdt-inspect.yml → 4 findings
# ✅ huggingface_transformers__self-scheduled-intel-gaudi.yml → 15 findings
# ✅ TheAlgorithms_Python__ruff.yml → 3 findings
# ✅ oracle_docker-images__build-and-push-oci-cli-image.yml → 6 findings
# ✅ mrdoob_three.js__ci.yml → 5 findings
# ✅ huggingface_transformers__self-push-amd-mi300-caller.yml → 2 findings
# ✅ facebook_react__runtime_build_and_test.yml → 19 findings
# ✅ Chalarangelo_30-seconds-of-code__test.yml → 1 findings
# ✅ twbs_bootstrap__release-notes.yml → 1 findings
# ✅ NVIDIA_cutlass__stale.yml → 3 findings
# ✅ denoland_deno__npm_publish.yml → 3 findings
# ✅ langchain-ai_langchain___lint.yml → 1 findings
# ✅ flutter_flutter__files-changed.yml → 2 findings
# ✅ oracle_docker-images__build-and-push-instantclient-images.yml → 9 findings
# ✅ electron_electron__pipeline-segment-electron-test.yml → 9 findings
# ✅ freeCodeCamp_freeCodeCamp__node.js-tests.yml → 5 findings
# ✅ vercel_next.js__build_and_deploy.yml → 22 findings
# ✅ langchain-ai_langchain___test_pydantic.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__classic-autogpts-ci.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__classic-frontend-ci.yml → 3 findings
# ✅ goldbergyoni_nodebestpractices__lint-and-generate-html-from-markdown.yml → 2 findings
# ✅ n8n-io_n8n__ci-postgres-mysql.yml → 12 findings
# ✅ tensorflow_tensorflow__cffconvert.yml → 1 findings
# ✅ NVIDIA_k8s-device-plugin__ci.yaml → 6 findings
# ✅ public-apis_public-apis__validate_links.yml → 2 findings
# ✅ facebook_react-native__on-issue-labeled.yml → 4 findings
# ✅ NVIDIA_k8s-device-plugin__basic-checks.yaml → 5 findings
# ✅ avelino_awesome-go__run-check.yaml → 1 findings
# ✅ excalidraw_excalidraw__autorelease-preview.yml → 4 findings
# ✅ facebook_rocksdb__benchmark-linux.yml → 1 findings
# ✅ google_grr__build.yml → 27 findings
# ✅ vercel_next.js__cancel.yml → 3 findings
# ✅ vercel_next.js__pull_request_stats.yml → 5 findings
# ✅ langchain-ai_langchain___test.yml → 1 findings
# ✅ facebook_rocksdb__pr-jobs.yml → 40 findings
# ✅ yangshun_tech-interview-handbook__tsc.yml → 1 findings
# ✅ facebook_folly__oss-build-and-test.yml → 19 findings
# ✅ freeCodeCamp_freeCodeCamp__e2e-third-party.yml → 9 findings
# ✅ alibaba_transmittable-thread-local__ci.yaml → 2 findings
# ✅ microsoft_TypeScript__codeql.yml → 1 findings
# ✅ excalidraw_excalidraw__size-limit.yml → 3 findings
# ✅ langgenius_dify__deploy-enterprise.yml → 3 findings
# ✅ airbnb_javascript__require-allow-edits.yml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__claude.yml → 2 findings
# ✅ electron_electron__pipeline-electron-build-and-test-and-nan.yml → 6 findings
# ✅ NVIDIA_cutlass__labeler.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__repo-stats.yml → 2 findings
# ✅ flutter_flutter__merge-changelog.yml → 2 findings
# ✅ langchain-ai_langchain__codspeed.yml → 4 findings
# ✅ freeCodeCamp_freeCodeCamp__github-labeler.yaml → 1 findings
# ✅ denoland_deno__version_bump.yml → 7 findings
# ✅ vercel_next.js__issue_wrong_template.yml → 2 findings
# ✅ google_auto__ci.yml → 7 findings
# ✅ facebook_fbthrift__getdeps_linux.yml → 1 findings
# ✅ microsoft_TypeScript__nightly.yaml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__platform-autogpt-deploy-dev.yaml → 3 findings
# ✅ langchain-ai_langchain__scheduled_test.yml → 11 findings
# ✅ oracle_docker-images__build-and-push-nosql-image.yml → 6 findings
# ✅ facebook_react-native__test-all.yml → 55 findings
# ✅ tensorflow_tensorflow__arm-ci.yml → 1 findings
# ✅ facebook_react-native__generate-changelog.yml → 2 findings
# ✅ huggingface_transformers__stale.yml → 1 findings
# ✅ ollama_ollama__test.yaml → 16 findings
# ✅ Chalarangelo_30-seconds-of-code__label.yml → 1 findings
# ✅ tensorflow_tensorflow__release-branch-cherrypick.yml → 4 findings
# ✅ alibaba_druid__ci.yaml → 3 findings
# ✅ n8n-io_n8n__e2e-tests.yml → 8 findings
# ✅ electron_electron__build.yml → 30 findings
# ✅ google_go-github__tests.yml → 1 findings
# ✅ EbookFoundation_free-programming-books__detect-conflicting-prs.yml → 3 findings
# ✅ facebook_react-native__publish-release.yml → 32 findings
# ✅ NVIDIA_k8s-device-plugin__image.yaml → 4 findings
# ✅ n8n-io_n8n__test-workflows-nightly.yml → 1 findings
# ✅ microsoft_TypeScript__set-version.yaml → 7 findings
# ✅ d3_d3__test.yml → 2 findings
# ✅ facebook_react__runtime_eslint_plugin_e2e.yml → 1 findings
# ✅ Significant-Gravitas_AutoGPT__classic-benchmark_publish_package.yml → 2 findings
# ✅ electron_electron__pipeline-electron-lint.yml → 1 findings
# ✅ langgenius_dify__api-tests.yml → 2 findings
# ✅ facebook_react-native__monitor-new-issues.yml → 3 findings
# ✅ huggingface_transformers__self-scheduled-caller.yml → 16 findings
# ✅ freeCodeCamp_freeCodeCamp__crowdin-upload.curriculum.yml → 8 findings
# ✅ krahets_hello-algo__go.yml → 2 findings
# ✅ excalidraw_excalidraw__test-coverage-pr.yml → 2 findings
# ✅ facebook_react__compiler_prereleases.yml → 4 findings
# ✅ facebook_react-native__bump-podfile-lock.yml → 2 findings
# ✅ facebook_folly__getdeps_windows.yml → 1 findings
# ✅ facebook_react-native__danger-pr.yml → 2 findings
# ✅ huggingface_transformers__build-nightly-ci-docker-images.yml → 11 findings
# ✅ huggingface_transformers__self-push.yml → 32 findings
# ✅ microsoft_TypeScript__accept-baselines-fix-lints.yaml → 1 findings
# ✅ EbookFoundation_free-programming-books__rtl-ltr-linter.yml → 6 findings
# ✅ huggingface_transformers__self-push-amd-mi210-caller.yml → 2 findings
# ✅ microsoft_TypeScript__update-package-lock.yaml → 1 findings
# ✅ awslabs_amazon-ecr-credential-helper__new-pull-requests.yml → 1 findings
# ✅ Significant-Gravitas_AutoGPT__classic-autogpt-ci.yml → 3 findings
# ✅ n8n-io_n8n__docker-build-push.yml → 17 findings
# ✅ electron_electron__macos-publish.yml → 11 findings
# ✅ d3_d3__deploy.yml → 2 findings
# ✅ huggingface_transformers__build-docker-images.yml → 52 findings
# ✅ google_jimfs__ci.yml → 7 findings
# ✅ microsoft_PowerToys__dependency-review.yml → 1 findings
# ✅ krahets_hello-algo__rust.yml → 3 findings
# ✅ oracle_opengrok__codeql-analysis.yml → 2 findings
# ✅ huggingface_transformers__push-important-models.yml → 13 findings
# ✅ huggingface_transformers__add-model-like.yml → 2 findings
# ✅ yt-dlp_yt-dlp__download.yml → 2 findings
# ✅ microsoft_TypeScript__ci.yml → 15 findings
# ✅ yt-dlp_yt-dlp__release-nightly.yml → 3 findings
# ✅ facebook_react__runtime_commit_artifacts.yml → 33 findings
# ✅ huggingface_transformers__trufflehog.yml → 2 findings
# ✅ huggingface_transformers__build-ci-docker-images.yml → 8 findings
# ✅ facebook_react__compiler_typescript.yml → 6 findings
# ✅ EbookFoundation_free-programming-books__comment-pr.yml → 1 findings
# ✅ facebook_folly__getdeps_mac.yml → 1 findings
# ✅ yt-dlp_yt-dlp__build.yml → 24 findings
# ✅ vuejs_vue__release-tag.yml → 3 findings
# ✅ EbookFoundation_free-programming-books__check-urls.yml → 11 findings
# ✅ vercel_next.js__retry_deploy_test.yml → 3 findings
# ✅ freeCodeCamp_freeCodeCamp__github-no-i18n-via-prs.yml → 2 findings
# ✅ nodejs_node__linters.yml → 1 findings
# ✅ flutter_flutter__tool-test-general.yml → 1 findings
# ✅ Significant-Gravitas_AutoGPT__platform-autgpt-deploy-prod.yml → 3 findings
# ✅ sindresorhus_awesome__main.yml → 2 findings
# ✅ airbnb_javascript__node-pretest.yml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__platform-frontend-ci.yml → 11 findings
# ✅ huggingface_transformers__self-push-amd-mi250-caller.yml → 2 findings
# ✅ vercel_next.js__popular.yml → 2 findings
# ✅ vercel_next.js__turbopack-benchmark.yml → 14 findings
# ✅ huggingface_transformers__benchmark.yml → 3 findings
# ✅ flutter_flutter__easy-cp.yml → 7 findings
# ✅ vuejs_vue__ci.yml → 13 findings
# ✅ huggingface_transformers__self-push-caller.yml → 7 findings
# ✅ freeCodeCamp_freeCodeCamp__docker-docr.yml → 11 findings
# ✅ nodejs_node__commit-lint.yml → 1 findings
# ✅ airbnb_javascript__node.yml → 18 findings
# ✅ open-webui_open-webui__format-backend.yaml → 2 findings
# ✅ public-apis_public-apis__test_of_push_and_pull.yml → 2 findings
# ✅ n8n-io_n8n__check-run-eligibility.yml → 1 findings
# ✅ tensorflow_tensorflow__arm-ci-extended.yml → 2 findings
# ✅ facebook_react__shared_lint.yml → 4 findings
# ✅ langchain-ai_langchain___integration_test.yml → 2 findings
# ✅ yangshun_tech-interview-handbook__lint.yml → 1 findings
# ✅ langgenius_dify__build-push.yml → 10 findings
# ✅ yt-dlp_yt-dlp__quick-test.yml → 2 findings
# ✅ tensorflow_tensorflow__arm-ci-extended-cpp.yml → 2 findings
# ✅ microsoft_vscode__monaco-editor.yml → 2 findings
# ✅ langchain-ai_langchain___test_release.yml → 3 findings
# ✅ google_blockly__develop_freeze.yml → 1 findings
# ✅ krahets_hello-algo__javascript.yml → 3 findings
# ✅ facebook_react-native__prebuild-ios-core.yml → 3 findings
# ✅ nodejs_node__daily-wpt-fyi.yml → 2 findings
# ✅ langchain-ai_langchain__check-broken-links.yml → 2 findings
# ✅ n8n-io_n8n__check-pr-title.yml → 2 findings
# ✅ n8n-io_n8n__e2e-flaky.yml → 4 findings
# ✅ facebook_facebook-android-sdk__stale.yml → 1 findings
# ✅ facebook_fbthrift__getdeps_mac.yml → 1 findings
# ✅ langgenius_dify__deploy-dev.yml → 4 findings
# ✅ oracle_graal__spring.yml → 2 findings
# ✅ goldbergyoni_nodebestpractices__automerge-prs.yml → 2 findings
# ✅ n8n-io_n8n__test-workflows-callable.yml → 5 findings
# ✅ n8n-io_n8n__test-workflows-pr-approved.yml → 1 findings
# ✅ rust-lang_rust__ci.yml → 5 findings
# ✅ facebook_react__shared_check_maintainer.yml → 1 findings
# ✅ NVIDIA_cutlass__blossom-ci.yml → 7 findings
# ✅ vercel_next.js__test_e2e_deploy_release.yml → 6 findings
# ✅ flutter_flutter__labeler.yml → 1 findings
# ✅ oracle_docker-images__build-and-push-nosql-sec-image.yml → 6 findings
# ✅ alibaba_transmittable-thread-local__strong_ci.yaml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__platform-backend-ci.yml → 3 findings
# ✅ awslabs_amazon-ecr-credential-helper__codeql.yml → 1 findings
# ✅ huggingface_transformers__self-scheduled-amd-caller.yml → 1 findings
# ✅ krahets_hello-algo__typescript.yml → 2 findings
# ✅ excalidraw_excalidraw__publish-docker.yml → 6 findings
# ✅ langchain-ai_langchain___test_doc_imports.yml → 1 findings
# ✅ google_blockly__assign_reviewers.yml → 1 findings
# ✅ freeCodeCamp_freeCodeCamp__deploy-client.yml → 10 findings
# ✅ EbookFoundation_free-programming-books__issues-pinner.yml → 2 findings
# ✅ vercel_next.js__issue_stale.yml → 1 findings
# ✅ oracle_graal__ni-layers.yml → 6 findings
# ✅ google_blockly__keyboard_plugin_test.yml → 2 findings
# ✅ electron_electron__non-maintainer-dependency-change.yml → 2 findings
# ✅ vercel_next.js__trigger_release.yml → 3 findings
# ✅ electron_electron__branch-created.yml → 2 findings
# ✅ electron_electron__pipeline-segment-electron-gn-check.yml → 9 findings
# ✅ excalidraw_excalidraw__autorelease-excalidraw.yml → 2 findings
# ✅ huggingface_transformers__slack-report.yml → 5 findings
# ✅ huggingface_transformers__self-nightly-past-ci-caller.yml → 16 findings
# ✅ electron_electron__windows-publish.yml → 9 findings
# ✅ f_awesome-chatgpt-prompts__csv_linter.yml → 2 findings
# ✅ excalidraw_excalidraw__test.yml → 2 findings
# ✅ nodejs_node__commit-queue.yml → 2 findings
# ✅ n8n-io_n8n__check-documentation-urls.yml → 2 findings
# ✅ alibaba_tengine__ci.yml → 5 findings
# ✅ Significant-Gravitas_AutoGPT__classic-benchmark-ci.yml → 6 findings
# ✅ ohmyzsh_ohmyzsh__dependencies.yml → 3 findings
# ✅ electron_electron__pipeline-electron-docs-only.yml → 1 findings
# ✅ vercel_next.js__issue_version.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__repo-pr-enforce-base-branch.yml → 1 findings
# ✅ oracle_graal__reachability-metadata.yml → 5 findings
# ✅ TheAlgorithms_Python__project_euler.yml → 7 findings
# ✅ ohmyzsh_ohmyzsh__main.yml → 1 findings
# ✅ electron_electron__clean-src-cache.yml → 1 findings
# ✅ vercel_next.js__update_react.yml → 4 findings
# ✅ langchain-ai_langchain__people.yml → 2 findings
# ✅ rust-lang_rust__post-merge.yml → 1 findings
# ✅ facebook_react__compiler_discord_notify.yml → 1 findings
# ✅ microsoft_TypeScript__lkg.yml → 2 findings
# ✅ langchain-ai_langchain__run_notebooks.yml → 5 findings
# ✅ facebook_folly__TagIt.yml → 7 findings
# ✅ krahets_hello-algo__dotnet.yml → 2 findings
# ✅ mrdoob_three.js__read-size.yml → 1 findings
# ✅ krahets_hello-algo__ruby.yml → 2 findings
# ✅ NVIDIA_k8s-device-plugin__helm.yaml → 1 findings
# ✅ huggingface_transformers__update_metdata.yml → 2 findings
# ✅ microsoft_PowerToys__spelling2.yml → 1 findings
# ✅ excalidraw_excalidraw__semantic-pr-title.yml → 2 findings
# ✅ axios_axios__pr.yml → 8 findings
# ✅ google_truth__ci.yml → 7 findings
# ✅ facebook_react-native__check-nightly.yml → 4 findings
# ✅ facebook_react-native__prebuild-ios-dependencies.yml → 4 findings
# ✅ huggingface_transformers__release-conda.yml → 3 findings
# ✅ nodejs_node__notify-on-review-wanted.yml → 1 findings
# ✅ n8n-io_n8n__e2e-tests-pr.yml → 9 findings
# ✅ facebook_facebook-android-sdk__needs-attention.yml → 3 findings
# ✅ langgenius_dify__translate-i18n-base-on-english.yml → 3 findings
# ✅ google_blockly__conventional-label.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__classic-autogpt-docker-cache-clean.yml → 4 findings
# ✅ yt-dlp_yt-dlp__release.yml → 26 findings
# ✅ google_blockly__appengine_deploy.yml → 5 findings
# ✅ huggingface_transformers__model_jobs_intel_gaudi.yml → 21 findings
# ✅ AUTOMATIC1111_stable-diffusion-webui__on_pull_request.yaml → 5 findings
# ✅ vercel_next.js__notify_release.yml → 6 findings
# ✅ n8n-io_n8n__test-workflows-pr-comment.yml → 1 findings
# ✅ oracle_opengrok__javadoc.yml → 3 findings
# ✅ AUTOMATIC1111_stable-diffusion-webui__run_tests.yaml → 2 findings
# ✅ electron_electron__linux-publish.yml → 9 findings
# ✅ denoland_deno__ci.yml → 18 findings
# ✅ facebook_react-native__check-for-reproducer.yml → 2 findings
# ✅ electron_electron__archaeologist-dig.yml → 6 findings
# ✅ huggingface_transformers__assign-reviewers.yml → 2 findings
# ✅ n8n-io_n8n__chromatic.yml → 5 findings
# ✅ krahets_hello-algo__cpp.yml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__i18n-validate-builds.yml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__docker-ghcr.yml → 2 findings
# ✅ twbs_bootstrap__docs.yml → 1 findings
# ✅ facebook_react-native__publish-bumped-packages.yml → 2 findings
# ✅ electron_electron__build-git-cache.yml → 7 findings
# ✅ flutter_flutter__content-aware-hash.yml → 2 findings
# ✅ NVIDIA_k8s-device-plugin__e2e.yaml → 3 findings
# ✅ google_go-querystring__linter.yml → 2 findings
# ✅ NVIDIA_k8s-device-plugin__code_scanning.yaml → 1 findings
# ✅ avelino_awesome-go__tests.yaml → 1 findings
# ✅ huggingface_transformers__self-nightly-caller.yml → 7 findings
# ✅ yt-dlp_yt-dlp__release-master.yml → 2 findings
# ✅ flutter_flutter__coverage.yml → 1 findings
# ✅ mrdoob_three.js__codeql-code-scanning.yml → 1 findings
# ✅ ohmyzsh_ohmyzsh__project.yml → 8 findings
# ✅ n8n-io_n8n__release-push-to-channel.yml → 19 findings
# ✅ facebook_react-native__retry-workflow.yml → 3 findings
# ✅ TheAlgorithms_Python__sphinx.yml → 4 findings
# ✅ f_awesome-chatgpt-prompts__ai_bot.yml → 1 findings
# ✅ ollama_ollama__latest.yaml → 3 findings
# ✅ alibaba_tengine__ci-arm64.yml → 4 findings
# ✅ electron_electron__pull-request-labeled.yml → 1 findings
# ✅ trekhleb_javascript-algorithms__CI.yml → 3 findings
# ✅ NVIDIA_k8s-device-plugin__variables.yaml → 1 findings
# ✅ facebook_react__runtime_discord_notify.yml → 1 findings
# ✅ facebook_watchman__package.yml → 8 findings
# ✅ langgenius_dify__db-migration-test.yml → 2 findings
# ✅ Snailclimb_JavaGuide__test.yml → 3 findings
# ✅ huggingface_transformers__self-push-amd.yml → 15 findings
# ✅ nodejs_node__label-flaky-test-issue.yml → 1 findings
# ✅ microsoft_terminal__spelling2.yml → 5 findings
# ✅ axios_axios__publish.yml → 11 findings
# ✅ facebook_react__runtime_releases_from_npm_manual.yml → 13 findings
# ✅ twbs_bootstrap__issue-close-require.yml → 1 findings
# ✅ vercel_next.js__turbopack-nextjs-build-integration-tests.yml → 2 findings
# ✅ ollama_ollama__release.yaml → 39 findings
# ✅ n8n-io_n8n__notify-pr-status.yml → 1 findings
# ✅ huggingface_transformers__check_tiny_models.yml → 3 findings
# ✅ oracle_opengrok__docker.yml → 2 findings
# ✅ ohmyzsh_ohmyzsh__installer.yml → 2 findings
# ✅ oracle_truffleruby__ci.yml → 18 findings
# ✅ huggingface_transformers__check_failed_tests.yml → 10 findings
# ✅ langchain-ai_langchain___compile_integration_test.yml → 1 findings
# ✅ langchain-ai_langchain__check_core_versions.yml → 2 findings
# ✅ denoland_deno__start_release.yml → 4 findings
# ✅ krahets_hello-algo__java.yml → 2 findings
# ✅ alibaba_ice__version.yml → 5 findings
# ✅ freeCodeCamp_freeCodeCamp__curriculum-i18n-submodule.yml → 1 findings
# ✅ facebook_react-native__create-draft-release.yml → 2 findings
# ✅ yt-dlp_yt-dlp__core.yml → 1 findings
# ✅ facebook_react-native__test-libraries-on-nightlies.yml → 3 findings
# ✅ huggingface_transformers__build-past-ci-docker-images.yml → 13 findings
# ✅ twbs_bootstrap__issue-labeled.yml → 1 findings
# ✅ krahets_hello-algo__dart.yml → 2 findings
# ✅ NVIDIA_cutlass__new-issues-to-triage-projects.yml → 1 findings
# ✅ facebook_react__compiler_playground.yml → 1 findings
# ✅ huggingface_transformers__doctest_job.yml → 4 findings
# ✅ axios_axios__notify.yml → 4 findings
# ✅ facebook_facebook-ios-sdk__needs-attention.yml → 3 findings
# ✅ n8n-io_n8n__security-trivy-scan-callable.yml → 3 findings
# ✅ facebook_react__shared_close_direct_sync_branch_prs.yml → 1 findings
# ✅ huggingface_transformers__self-scheduled-amd-mi300-caller.yml → 10 findings
# ✅ freeCodeCamp_freeCodeCamp__e2e-playwright.yml → 10 findings
# ✅ microsoft_TypeScript__sync-wiki.yml → 1 findings
# ✅ NVIDIA_k8s-device-plugin__deploy-to-pages.yml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__platform-dev-deploy-event-dispatcher.yml → 5 findings
# ✅ rust-lang_rust__dependencies.yml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__github-autoclose.yml → 2 findings
# ✅ alibaba_tengine__test-nginx-core.yml → 5 findings
# ✅ langgenius_dify__deploy-rag-dev.yml → 3 findings
# ✅ n8n-io_n8n__docker-images-benchmark.yml → 2 findings
# ✅ huggingface_transformers__self-scheduled-amd-mi250-caller.yml → 10 findings
# ✅ huggingface_transformers__upload_pr_documentation.yml → 2 findings
# ✅ facebook_react-native__nightly.yml → 24 findings
# ✅ yt-dlp_yt-dlp__sanitize-comment.yml → 1 findings
# ✅ n8n-io_n8n__ci-master.yml → 6 findings
# ✅ microsoft_terminal__winget.yml → 2 findings
# ✅ microsoft_TypeScript__sync-branch.yaml → 2 findings
# ✅ excalidraw_excalidraw__locales-coverage.yml → 3 findings
# ✅ facebook_react__runtime_prereleases.yml → 8 findings
# ✅ langchain-ai_langchain__api_doc_build.yml → 5 findings
# ✅ excalidraw_excalidraw__cancel.yml → 2 findings
# ✅ huggingface_transformers__model_jobs.yml → 21 findings
# ✅ krahets_hello-algo__python.yml → 1 findings
# ✅ freeCodeCamp_freeCodeCamp__docker-docr-cleanup.yml → 2 findings
# ✅ n8n-io_n8n__release-create-pr.yml → 2 findings
# ✅ facebook_rocksdb__nightly.yml → 10 findings
# ✅ alibaba_tengine__test-ntls.yml → 6 findings
# ✅ n8n-io_n8n__benchmark-destroy-nightly.yml → 1 findings
# ✅ vercel_next.js__setup-nextjs-build.yml → 6 findings
# ✅ freeCodeCamp_freeCodeCamp__crowdin-upload.client-ui.yml → 4 findings
# ✅ oracle_opengrok__build.yml → 3 findings
# ✅ vercel_next.js__turbopack-nextjs-dev-integration-tests.yml → 2 findings
# ✅ oracle_docker-images__build-and-push-dev-images.yml → 46 findings
# ✅ nodejs_node__auto-start-ci.yml → 1 findings
# ✅ microsoft_TypeScript__create-cherry-pick-pr.yml → 2 findings
# ✅ vercel_next.js__retry_test.yml → 3 findings
# ✅ facebook_fbthrift__getdeps_windows.yml → 1 findings
# ✅ langgenius_dify__docker-build.yml → 4 findings
# ✅ AUTOMATIC1111_stable-diffusion-webui__warns_merge_master.yml → 1 findings
# ✅ facebook_create-react-app__lint.yml → 2 findings
# ✅ facebook_folly__getdeps_linux.yml → 1 findings
# ✅ google_go-querystring__tests.yml → 2 findings
# ✅ twbs_bootstrap__calibreapp-image-actions.yml → 1 findings
# ✅ avelino_awesome-go__check-for-spammy-issues.yml → 2 findings
# ✅ google_dagger__release.yml → 16 findings
# ✅ facebook_watchman__getdeps_mac.yml → 2 findings
# ✅ oracle_truffleruby__prism.yml → 3 findings
# ✅ facebook_create-react-app__e2e-base.yml → 2 findings
# ✅ alibaba_ice__coverage.yml → 3 findings
# ✅ NVIDIA_k8s-device-plugin__publish-helm.yaml → 10 findings
# ✅ facebook_react-native__cache-reaper.yml → 2 findings
# ✅ krahets_hello-algo__kotlin.yml → 2 findings
# ✅ microsoft_TypeScript__insiders.yaml → 2 findings
# ✅ tensorflow_tensorflow__issue-on-pr-rollback.yml → 1 findings
# ✅ vercel_next.js__code_freeze.yml → 2 findings
# ✅ NVIDIA_k8s-device-plugin__golang.yaml → 4 findings
# ✅ facebook_create-react-app__build-and-test.yml → 8 findings
# ✅ huggingface_transformers__doctests.yml → 7 findings
# ✅ google_blockly__build.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__repo-pr-label.yml → 3 findings
# ✅ tensorflow_tensorflow__pylint-presubmit.yml → 3 findings
# ✅ vercel_next.js__test-turbopack-rust-bench-test.yml → 1 findings
# ✅ vercel_next.js__rspack-nextjs-dev-integration-tests.yml → 2 findings
# ✅ huggingface_transformers__build_pr_documentation.yml → 1 findings
# ✅ mrdoob_three.js__report-size.yml → 2 findings
# ✅ tensorflow_tensorflow__update-rbe.yml → 1 findings
# ✅ electron_electron__issue-unlabeled.yml → 1 findings
# ✅ avelino_awesome-go__pull-request-first-comment.yaml → 2 findings
# ✅ jwasham_coding-interview-university__links_checker.yml → 8 findings
# ✅ nodejs_node__notify-on-push.yml → 2 findings
# ✅ huggingface_transformers__self-scheduled-intel-gaudi3-caller.yml → 11 findings
# ✅ nodejs_node__label-pr.yml → 1 findings
# ✅ facebook_react-native__autorebase.yml → 2 findings
# ✅ Significant-Gravitas_AutoGPT__repo-workflow-checker.yml → 2 findings
# ✅ twbs_bootstrap__js.yml → 1 findings
# ✅ denoland_deno__promote_to_release.yml → 21 findings
# ✅ vercel_next.js__test_examples.yml → 2 findings
# ✅ krahets_hello-algo__c.yml → 2 findings
# ✅ electron_electron__pipeline-segment-node-nan-test.yml → 6 findings
# ✅ avelino_awesome-go__site-deploy.yaml → 2 findings
# ✅ freeCodeCamp_freeCodeCamp__github-spam.yml → 2 findings
# ✅ axios_axios__labeler.yml → 4 findings
# ✅ vercel_next.js__update_fonts_data.yml → 2 findings
# ✅ huggingface_transformers__build_documentation.yml → 1 findings
# ✅ open-webui_open-webui__deploy-to-hf-spaces.yml → 4 findings
# ✅ public-apis_public-apis__test_of_validate_package.yml → 2 findings
# ✅ vercel_next.js__build_and_test.yml → 82 findings
# ✅ facebook_watchman__getdeps_windows.yml → 2 findings
# ✅ vercel_next.js__rspack-nextjs-build-integration-tests.yml → 2 findings
# ✅ open-webui_open-webui__format-build-frontend.yaml → 5 findings
# ✅ tensorflow_tensorflow__arm-cd.yml → 2 findings
# ✅ huggingface_transformers__new_model_pr_merged_notification.yml → 2 findings
# ✅ n8n-io_n8n__ci-pull-requests.yml → 9 findings
# ✅ langchain-ai_langchain__check_new_docs.yml → 4 findings
# ✅ krahets_hello-algo__swift.yml → 2 findings
# ✅ airbnb_javascript__rebase.yml → 4 findings
# ✅ vercel_next.js__integration_tests_reusable.yml → 11 findings
# ✅ microsoft_TypeScript__twoslash-repros.yaml → 3 findings
# ✅ NVIDIA_k8s-device-plugin__release.yaml → 5 findings
# ✅ facebook_rocksdb__nightly-candidate.yml → 1 findings
# ✅ n8n-io_n8n__linting-reusable.yml → 1 findings
# ✅ open-webui_open-webui__build-release.yml → 6 findings
# ✅ denoland_deno__post_publish.yml → 5 findings
# ✅ microsoft_vscode__no-yarn-lock-changes.yml → 2 findings
# ✅ huggingface_transformers__ssh-runner.yml → 17 findings
# ✅ freeCodeCamp_freeCodeCamp__i18n-validate-prs.yml → 2 findings
# ✅ langgenius_dify__web-tests.yml → 3 findings
# ✅ axios_axios__sponsors.yml → 5 findings
# ✅ alibaba_ice__canary.yml → 7 findings
# ✅ alibaba_ice__website.yml → 4 findings
# ✅ Significant-Gravitas_AutoGPT__codeql.yml → 1 findings
# ✅ google_blockly__welcome_new_contributors.yml → 1 findings
# ✅ google_go-github__linter.yml → 1 findings
# ✅ vercel_next.js__trigger_release_new.yml → 2 findings
# ✅ microsoft_TypeScript__release-branch-artifact.yaml → 1 findings
# ✅ f_awesome-chatgpt-prompts__publish.yml → 4 findings
# ✅ microsoft_vscode__no-package-lock-changes.yml → 2 findings
# ✅ microsoft_TypeScript__new-release-branch.yaml → 9 findings
# ✅ microsoft_TypeScript__copilot-setup-steps.yml → 1 findings
# ✅ microsoft_PowerToys__package-submissions.yml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__classic-forge-ci.yml → 7 findings
# ✅ vercel_next.js__issue_lock.yml → 1 findings
# ✅ oracle_docker-images__super-linter.yml → 1 findings
# ✅ EbookFoundation_free-programming-books__fpb-lint.yml → 2 findings
# ✅ langgenius_dify__vdb-tests.yml → 4 findings
# ✅ axios_axios__npm-tag.yml → 3 findings
# ✅ facebook_react-native__needs-attention.yml → 3 findings
# ✅ twbs_bootstrap__cspell.yml → 1 findings
# ✅ electron_electron__pipeline-electron-build-and-test.yml → 2 findings
# ✅ oracle_opengrok__release.yml → 6 findings
# ✅ google_dagger__ci.yml → 24 findings
# ✅ langchain-ai_langchain__check_diffs.yml → 18 findings
# ✅ TheAlgorithms_Python__directory_writer.yml → 2 findings
# ✅ vercel_next.js__graphite_ci_optimizer.yml → 2 findings
# ✅ oracle_graal__quarkus.yml → 1 findings
# ✅ n8n-io_n8n__units-tests-reusable.yml → 1 findings
# ✅ microsoft_TypeScript__pr-modified-files.yml → 2 findings
# ✅ n8n-io_n8n__e2e-reusable.yml → 6 findings
# ✅ denoland_deno__wpt_epoch.yml → 2 findings
# ✅ huggingface_transformers__self-scheduled.yml → 22 findings
# ✅ TheAlgorithms_Python__build.yml → 3 findings
# ✅ Significant-Gravitas_AutoGPT__classic-python-checks.yml → 10 findings
# ✅ yt-dlp_yt-dlp__codeql.yml → 1 findings
# ✅ langgenius_dify__tool-test-sdks.yaml → 1 findings
# ✅ huggingface_transformers__self-past-caller.yml → 4 findings
# ✅ axios_axios__ci.yml → 3 findings
# ✅ alibaba_ice__ci.yml → 3 findings
# ✅ facebook_react__devtools_regression_tests.yml → 5 findings
# ✅ google_grr__publish-pypi.yml → 11 findings
# ✅ freeCodeCamp_freeCodeCamp__deploy-api.yml → 8 findings
# ✅ awslabs_amazon-ecr-credential-helper__check-links.yml → 3 findings
# ✅ electron_electron__pipeline-segment-electron-build.yml → 9 findings
# ✅ Genymobile_scrcpy__release.yml → 31 findings
# ✅ facebook_watchman__getdeps_linux.yml → 2 findings
# ✅ excalidraw_excalidraw__lint.yml → 2 findings
# ✅ langchain-ai_langchain__codespell.yml → 1 findings
# ✅ vercel_next.js__issue_bankrupt.yml → 2 findings
#
# ✅ Parsed 506 workflow result files to ../tools_output/zizmor/workflow_with_issues

# %% [markdown]
# SCORECARD ___________________________________________________________________________________

# %% [markdown]
# ./scorecard --local=. > tools_output/scorecard/findings.txt

# %%
import os
import shutil
import subprocess
import json
from pathlib import Path
from tqdm import tqdm

# Paths
WORKFLOW_DIR = Path("../.github/workflows")
TEMP_REPO_DIR = Path("scorecard_tmp_repo")
FINDINGS_PATH = Path("../tools_output/scorecard/findings_all.json")
FINDINGS_PATH.parent.mkdir(parents=True, exist_ok=True)

# Clean previous run
if TEMP_REPO_DIR.exists():
    shutil.rmtree(TEMP_REPO_DIR)
TEMP_REPO_DIR.mkdir(parents=True)
(TEMP_REPO_DIR / ".github" / "workflows").mkdir(parents=True, exist_ok=True)

all_workflow_results = []

yml_files = list(WORKFLOW_DIR.glob("*.yml")) + list(WORKFLOW_DIR.glob("*.yaml"))
print(f"Running Scorecard simulation on {len(yml_files)} workflows...")

for wf in tqdm(yml_files, desc="Simulating"):
    # Clean temp workflows folder
    temp_wf_dir = TEMP_REPO_DIR / ".github" / "workflows"
    for f in temp_wf_dir.glob("*"):
        f.unlink()

    # Copy workflow into temp repo
    temp_wf_path = temp_wf_dir / wf.name
    shutil.copy(wf, temp_wf_path)

    # Run Scorecard
    result = subprocess.run(
        ["../../tools/scorecard/scorecard", f"--local={TEMP_REPO_DIR}", "--show-details", "--format=json"],
        capture_output=True,
        text=True
    )

    try:
        json_data = json.loads(result.stdout)
    except json.JSONDecodeError:
        continue

    json_data["workflow"] = wf.name
    all_workflow_results.append(json_data)

# Save all results to a single JSON file
with open(FINDINGS_PATH, "w", encoding="utf-8") as f:
    json.dump(all_workflow_results, f, indent=2)

print(f"[✓] All scorecard workflow results saved to: {FINDINGS_PATH}")
# Out:
# Running Scorecard simulation on 596 workflows...
# Simulating:   0%|          | 0/596 [00:00<?, ?it/s]
# Simulating: 100%|██████████| 596/596 [03:31<00:00,  2.82it/s]
# [✓] All scorecard workflow results saved to: ../tools_output/scorecard/findings_all.json

# %%
import json
import re
from pathlib import Path
from collections import defaultdict

# Paths
input_file = Path("../tools_output/scorecard/findings_all.json")
output_dir = Path("../tools_output/scorecard/workflow_with_issues1")
output_dir.mkdir(parents=True, exist_ok=True)

# Relevant rules
relevant_rules = {
    "Dangerous-Workflow",
    "Pinned-Dependencies",
    "Token-Permissions",
    "SAST",
}

# Regex to capture line numbers like ":171"
line_regex = re.compile(r":(\d+)\b")

with open(input_file, "r", encoding="utf-8") as f:
    workflows_data = json.load(f)

saved = 0
for wf in workflows_data:
    workflow_name = wf.get("workflow")
    checks = wf.get("checks", [])
    findings = []

    for check in checks:
        name = check.get("name")
        score = check.get("score")
        if name in relevant_rules and score is not None and score < 10 and score != -1:
            raw_details = check.get("details") or []
            affected_lines = []
            for detail in raw_details:
                for m in line_regex.finditer(detail):
                    affected_lines.append(int(m.group(1)))

            findings.append({
                "rule": name,
                "score": score,
                "reason": check.get("reason"),
                "lines": sorted(set(affected_lines)),
                "raw_details": raw_details,
                "documentation": check.get("documentation", {})
            })

    if not findings:
        continue

    by_rule = defaultdict(int)
    for f in findings:
        by_rule[f["rule"]] += 1

    result = {
        "workflow": workflow_name,
        "tool": "scorecard",
        "summary": {
            "total_findings": len(findings),
            "by_rule": dict(by_rule)
        },
        "findings": findings
    }

    out_path = output_dir / f"{workflow_name}.json"
    with open(out_path, "w", encoding="utf-8") as f_out:
        json.dump(result, f_out, indent=2)
        saved += 1

print(f"Saved {saved} workflow files to {output_dir}")
# Out:
# Saved 593 workflow files to ../tools_output/scorecard/workflow_with_issues1

# %% [markdown]
# SEMGREP _________________________________________________________________________________________

# %% [markdown]
# semgrep --config p/github-actions .github/workflows --json > tools_output/semgrep/findings.json

# %%
import json
from pathlib import Path
from collections import defaultdict

# Input and output paths
input_file = Path("../tools_output/semgrep/findings.json")
workflow_output_dir = Path("../tools_output/semgrep/workflow_with_issues")
workflow_output_dir.mkdir(parents=True, exist_ok=True)

# Load Semgrep findings JSON
with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# Group findings by file (workflow)
grouped = defaultdict(list)
for finding in data.get("results", []):
    path = Path(finding.get("path", ""))
    if not path.name:
        continue

    workflow_name = path.name
    grouped[workflow_name].append(finding)

# Normalize and save
for wf_name, findings in grouped.items():
    structured = []
    rule_counts = defaultdict(int)

    for f in findings:
        rule_id = f.get("check_id", "unknown").split('.')[-1]
        rule_counts[rule_id] += 1

        structured.append({
            "rule": rule_id,
            "line": f.get("start", {}).get("line"),
            "code": f.get("extra", {}).get("lines"),
            "note": f.get("extra", {}).get("message"),
            "documentation": f.get("extra", {}).get("shortlink")
        })

    output_data = {
        "workflow": wf_name,
        "tool": "semgrep",
        "summary": {
            "total_findings": len(structured),
            "by_rule": dict(rule_counts)
        },
        "findings": structured
    }

    with open(workflow_output_dir / f"{wf_name}.json", "w", encoding="utf-8") as f_out:
        json.dump(output_data, f_out, indent=2)

print(f"[✓] Saved {len(list(workflow_output_dir.glob('*.json')))} normalized workflow result files to {workflow_output_dir}")
# Out:
# [✓] Saved 55 normalized workflow result files to ../tools_output/semgrep/workflow_with_issues

# %% [markdown]
# GGSHIELD _______________________________________________________________________________________

# %% [markdown]
# ./ggshield secret scan --all-secrets path .github/workflows/ --recursive --json > tools_output/ggshield/findings.json

# %%
import json
from pathlib import Path

# Paths
input_path = Path("../tools_output/ggshield/findings.json")
output_dir = Path("../tools_output/ggshield/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Load JSON data
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

saved = 0

# Extract and normalize
for entity in data.get("entities_with_incidents", []):
    incidents = entity.get("incidents", [])
    if not incidents:
        continue

    filename = Path(entity["filename"]).name
    findings = []

    for inc in incidents:
        rule = inc.get("policy", "secret-detected")
        documentation = inc.get("detector_documentation")
        note = inc.get("type")

        for occ in inc.get("occurrences", []):
            findings.append({
                "rule": rule,
                "line": occ.get("line_start"),
                "code": occ.get("match"),
                "note": note,
                "documentation": documentation
            })

    if not findings:
        continue

    # Build summary by rule
    by_rule = {}
    for finding in findings:
        r = finding["rule"]
        by_rule[r] = by_rule.get(r, 0) + 1

    result = {
        "workflow": filename,
        "tool": "ggshield",
        "summary": {
            "total_findings": len(findings),
            "by_rule": by_rule
        },
        "findings": findings
    }

    with open(output_dir / f"{filename}.json", "w", encoding="utf-8") as out_f:
        json.dump(result, out_f, indent=2)
        saved += 1

print(f"[✓] Saved {saved} normalized workflow result files to {output_dir}")
# Out:
# [✓] Saved 1 normalized workflow result files to ../tools_output/ggshield/workflow_with_issues

# %%
import subprocess
import csv
from pathlib import Path

# Setup
TOOL = "ggshield"
WORKFLOW_DIR = Path("../.github/workflows").resolve()
GGSHIELD_PATH = Path("../../tools/ggshield/ggshield").resolve()
OUTPUT_CSV = f"{TOOL}_issue_status.csv"

results = []
issue_count = 0

workflow_files = list(WORKFLOW_DIR.glob("*.yml")) + list(WORKFLOW_DIR.glob("*.yaml"))
print(f"[INFO] Found {len(workflow_files)} workflow files.\n")

for wf in sorted(workflow_files):
    print(f"[▶] Scanning: {wf.name}")

    try:
        completed = subprocess.run(
            [str(GGSHIELD_PATH), "secret", "scan", "--all-secrets", "path", str(wf)],
            capture_output=True,
            text=True
        )

        stdout = completed.stdout.strip()
        stderr = completed.stderr.strip()

        if "> " in stdout and "secret detected" in stdout:
            status = "issue"
            issue_count += 1
        else:
            status = "clean"

        results.append((wf.name, status))
        print(f"    [✓] {status.upper()}")

    except Exception as e:
        print(f"    [✗] Error on {wf.name}: {e}")
        results.append((wf.name, "error"))

# Save to CSV
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["file_name", "status"])
    writer.writerows(results)

print(f"\n[✅] Total workflows with issues: {issue_count}")
print(f"[📁] CSV saved to: {OUTPUT_CSV}")
# Out:
# [INFO] Found 596 workflow files.
#
# [▶] Scanning: AUTOMATIC1111_stable-diffusion-webui__on_pull_request.yaml
#     [✓] CLEAN
# [▶] Scanning: AUTOMATIC1111_stable-diffusion-webui__run_tests.yaml
#     [✓] CLEAN
# [▶] Scanning: AUTOMATIC1111_stable-diffusion-webui__warns_merge_master.yml
#     [✓] CLEAN
# [▶] Scanning: Chalarangelo_30-seconds-of-code__deploy-production.yml
#     [✓] CLEAN
# [▶] Scanning: Chalarangelo_30-seconds-of-code__label.yml
#     [✓] CLEAN
# [▶] Scanning: Chalarangelo_30-seconds-of-code__stale.yml
#     [✓] CLEAN
# [▶] Scanning: Chalarangelo_30-seconds-of-code__test.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__check-urls.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__comment-pr.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__detect-conflicting-prs.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__fpb-lint.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__issues-pinner.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__rtl-ltr-linter.yml
#     [✓] CLEAN
# [▶] Scanning: EbookFoundation_free-programming-books__stale.yml
#     [✓] CLEAN
# [▶] Scanning: Genymobile_scrcpy__release.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__apidiff.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__cache-cleanup.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__ci.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__codeql-analysis.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__dependency-review.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__fuzz.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__fvt-main.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__fvt-pr.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__fvt.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__i386.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__scorecard.yml
#     [✓] CLEAN
# [▶] Scanning: IBM_sarama__stale.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_cutlass__blossom-ci.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_cutlass__labeler.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_cutlass__new-issues-to-triage-projects.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_cutlass__stale.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__basic-checks.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__ci.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__code_scanning.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__deploy-to-pages.yml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__e2e.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__golang.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__helm.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__image.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__publish-helm.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__release.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__stale.yaml
#     [✓] CLEAN
# [▶] Scanning: NVIDIA_k8s-device-plugin__variables.yaml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-autogpt-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-autogpt-docker-cache-clean.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-autogpt-docker-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-autogpt-docker-release.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-autogpts-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-benchmark-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-benchmark_publish_package.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-forge-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-frontend-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__classic-python-checks.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__claude.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__platform-autgpt-deploy-prod.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__platform-autogpt-deploy-dev.yaml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__platform-backend-ci.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__platform-dev-deploy-event-dispatcher.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__platform-frontend-ci.yml
#     [✓] ISSUE
# [▶] Scanning: Significant-Gravitas_AutoGPT__repo-close-stale-issues.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__repo-pr-enforce-base-branch.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__repo-pr-label.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__repo-stats.yml
#     [✓] CLEAN
# [▶] Scanning: Significant-Gravitas_AutoGPT__repo-workflow-checker.yml
#     [✓] CLEAN
# [▶] Scanning: Snailclimb_JavaGuide__test.yml
#     [✓] CLEAN
# [▶] Scanning: TheAlgorithms_Python__build.yml
#     [✓] CLEAN
# [▶] Scanning: TheAlgorithms_Python__directory_writer.yml
#     [✓] CLEAN
# [▶] Scanning: TheAlgorithms_Python__project_euler.yml
#     [✓] CLEAN
# [▶] Scanning: TheAlgorithms_Python__ruff.yml
#     [✓] CLEAN
# [▶] Scanning: TheAlgorithms_Python__sphinx.yml
#     [✓] CLEAN
# [▶] Scanning: airbnb_javascript__node-pretest.yml
#     [✓] CLEAN
# [▶] Scanning: airbnb_javascript__node.yml
#     [✓] CLEAN
# [▶] Scanning: airbnb_javascript__rebase.yml
#     [✓] CLEAN
# [▶] Scanning: airbnb_javascript__require-allow-edits.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_druid__ci.yaml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__canary.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__ci.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__coverage.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__release.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__version.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_ice__website.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_tengine__ci-arm64.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_tengine__ci.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_tengine__test-nginx-core.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_tengine__test-ntls.yml
#     [✓] CLEAN
# [▶] Scanning: alibaba_transmittable-thread-local__ci.yaml
#     [✓] CLEAN
# [▶] Scanning: alibaba_transmittable-thread-local__strong_ci.yaml
#     [✓] CLEAN
# [▶] Scanning: avelino_awesome-go__check-for-spammy-issues.yml
#     [✓] CLEAN
# [▶] Scanning: avelino_awesome-go__pull-request-first-comment.yaml
#     [✓] CLEAN
# [▶] Scanning: avelino_awesome-go__run-check.yaml
#     [✓] CLEAN
# [▶] Scanning: avelino_awesome-go__site-deploy.yaml
#     [✓] CLEAN
# [▶] Scanning: avelino_awesome-go__tests.yaml
#     [✓] CLEAN
# [▶] Scanning: awslabs_amazon-ecr-credential-helper__build.yaml
#     [✓] CLEAN
# [▶] Scanning: awslabs_amazon-ecr-credential-helper__check-links.yml
#     [✓] CLEAN
# [▶] Scanning: awslabs_amazon-ecr-credential-helper__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: awslabs_amazon-ecr-credential-helper__new-pull-requests.yml
#     [✓] CLEAN
# [▶] Scanning: awslabs_amazon-ecr-credential-helper__review-dependencies.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__ci.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__codeql-analysis.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__depsreview.yaml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__labeler.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__notify.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__npm-tag.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__pr-guard.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__pr.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__publish.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__sponsors.yml
#     [✓] CLEAN
# [▶] Scanning: axios_axios__stale.yml
#     [✓] CLEAN
# [▶] Scanning: d3_d3__deploy.yml
#     [✓] CLEAN
# [▶] Scanning: d3_d3__test.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__cargo_publish.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__ci.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__node_compat_test.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__npm_publish.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__post_publish.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__promote_to_release.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__start_release.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__version_bump.yml
#     [✓] CLEAN
# [▶] Scanning: denoland_deno__wpt_epoch.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__archaeologist-dig.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__audit-branch-ci.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__branch-created.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__build-git-cache.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__build.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__clean-src-cache.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__issue-commented.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__issue-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__issue-opened.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__issue-transferred.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__issue-unlabeled.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__linux-publish.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__macos-publish.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__non-maintainer-dependency-change.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-electron-build-and-test-and-nan.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-electron-build-and-test.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-electron-docs-only.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-electron-lint.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-segment-electron-build.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-segment-electron-gn-check.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-segment-electron-test.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pipeline-segment-node-nan-test.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__pull-request-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__scorecards.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__semantic.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__stable-prep-items.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__stale.yml
#     [✓] CLEAN
# [▶] Scanning: electron_electron__windows-publish.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__autorelease-excalidraw.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__autorelease-preview.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__build-docker.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__cancel.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__lint.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__locales-coverage.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__publish-docker.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__semantic-pr-title.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__sentry-production.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__size-limit.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__test-coverage-pr.yml
#     [✓] CLEAN
# [▶] Scanning: excalidraw_excalidraw__test.yml
#     [✓] CLEAN
# [▶] Scanning: f_awesome-chatgpt-prompts__ai_bot.yml
#     [✓] CLEAN
# [▶] Scanning: f_awesome-chatgpt-prompts__auto_commands.yml
#     [✓] CLEAN
# [▶] Scanning: f_awesome-chatgpt-prompts__csv_linter.yml
#     [✓] CLEAN
# [▶] Scanning: f_awesome-chatgpt-prompts__publish.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_create-react-app__build-and-test.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_create-react-app__e2e-base.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_create-react-app__lint.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_facebook-android-sdk__needs-attention.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_facebook-android-sdk__stale.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_facebook-ios-sdk__needs-attention.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_facebook-ios-sdk__stale.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_fbthrift__getdeps_linux.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_fbthrift__getdeps_mac.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_fbthrift__getdeps_windows.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_folly__TagIt.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_folly__getdeps_linux.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_folly__getdeps_mac.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_folly__getdeps_windows.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_folly__oss-build-and-test.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_hhvm__ubuntu.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_mcrouter__build.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__autorebase.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__bump-podfile-lock.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__cache-reaper.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__check-for-reproducer.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__check-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__close-pr.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__create-draft-release.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__create-release.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__danger-pr.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__generate-changelog.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__monitor-new-issues.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__needs-attention.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__nightly.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__on-issue-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__prebuild-ios-core.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__prebuild-ios-dependencies.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__publish-bumped-packages.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__publish-release.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__retry-workflow.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__stale-bot.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__test-all.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react-native__test-libraries-on-nightlies.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_discord_notify.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_playground.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_prereleases.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_prereleases_manual.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_prereleases_nightly.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__compiler_typescript.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__devtools_regression_tests.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_build_and_test.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_commit_artifacts.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_discord_notify.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_eslint_plugin_e2e.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_fuzz_tests.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_prereleases.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_prereleases_manual.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_prereleases_nightly.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__runtime_releases_from_npm_manual.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_check_maintainer.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_cleanup_merged_branch_caches.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_cleanup_stale_branch_caches.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_close_direct_sync_branch_prs.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_label_core_team_prs.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_lint.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_react__shared_stale.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_rocksdb__benchmark-linux.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_rocksdb__nightly-candidate.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_rocksdb__nightly.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_rocksdb__pr-jobs-candidate.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_rocksdb__pr-jobs.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_watchman__getdeps_linux.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_watchman__getdeps_mac.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_watchman__getdeps_windows.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_watchman__package.yml
#     [✓] CLEAN
# [▶] Scanning: facebook_watchman__release.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__content-aware-hash.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__coverage.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__easy-cp.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__files-changed.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__labeler.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__lock.yaml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__merge-changelog.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__mirror.yml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__no-response.yaml
#     [✓] CLEAN
# [▶] Scanning: flutter_flutter__tool-test-general.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__crowdin-download.client-ui.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__crowdin-upload.client-ui.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__crowdin-upload.curriculum.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__curriculum-i18n-submodule.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__deploy-api.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__deploy-client.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__docker-docr-cleanup.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__docker-docr.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__docker-ghcr.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__e2e-playwright.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__e2e-third-party.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__github-autoclose.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__github-labeler.yaml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__github-no-i18n-via-prs.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__github-no-web-commits.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__github-spam.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__i18n-validate-builds.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__i18n-validate-prs.yml
#     [✓] CLEAN
# [▶] Scanning: freeCodeCamp_freeCodeCamp__node.js-tests.yml
#     [✓] CLEAN
# [▶] Scanning: github_gitignore__stale.yml
#     [✓] CLEAN
# [▶] Scanning: goldbergyoni_nodebestpractices__automerge-prs.yml
#     [✓] CLEAN
# [▶] Scanning: goldbergyoni_nodebestpractices__lint-and-generate-html-from-markdown.yml
#     [✓] CLEAN
# [▶] Scanning: goldbergyoni_nodebestpractices__update-date-in-last-update-badge.yml
#     [✓] CLEAN
# [▶] Scanning: google_auto__ci.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__appengine_deploy.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__assign_reviewers.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__browser_test.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__build.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__conventional-label.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__develop_freeze.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__keyboard_plugin_test.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__tag_module_cleanup.yml
#     [✓] CLEAN
# [▶] Scanning: google_blockly__welcome_new_contributors.yml
#     [✓] CLEAN
# [▶] Scanning: google_dagger__ci.yml
#     [✓] CLEAN
# [▶] Scanning: google_dagger__release.yml
#     [✓] CLEAN
# [▶] Scanning: google_go-github__linter.yml
#     [✓] CLEAN
# [▶] Scanning: google_go-github__tests.yml
#     [✓] CLEAN
# [▶] Scanning: google_go-querystring__linter.yml
#     [✓] CLEAN
# [▶] Scanning: google_go-querystring__tests.yml
#     [✓] CLEAN
# [▶] Scanning: google_grr__build.yml
#     [✓] CLEAN
# [▶] Scanning: google_grr__publish-pypi.yml
#     [✓] CLEAN
# [▶] Scanning: google_jimfs__ci.yml
#     [✓] CLEAN
# [▶] Scanning: google_truth__ci.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__add-model-like.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__assign-reviewers.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__benchmark.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build-ci-docker-images.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build-docker-images.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build-nightly-ci-docker-images.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build-past-ci-docker-images.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build_documentation.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__build_pr_documentation.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__check_failed_tests.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__check_tiny_models.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__doctest_job.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__doctests.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__model_jobs.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__model_jobs_intel_gaudi.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__new_model_pr_merged_notification.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__pr-style-bot.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__push-important-models.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__release-conda.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-comment-ci.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-nightly-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-nightly-past-ci-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-past-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push-amd-mi210-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push-amd-mi250-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push-amd-mi300-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push-amd.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-push.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-amd-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-amd-mi250-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-amd-mi300-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-intel-gaudi.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled-intel-gaudi3-caller.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__self-scheduled.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__slack-report.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__ssh-runner.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__stale.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__trufflehog.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__update_metdata.yml
#     [✓] CLEAN
# [▶] Scanning: huggingface_transformers__upload_pr_documentation.yml
#     [✓] CLEAN
# [▶] Scanning: jwasham_coding-interview-university__links_checker.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__c.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__cpp.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__dart.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__dotnet.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__go.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__java.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__javascript.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__kotlin.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__python.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__ruby.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__rust.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__swift.yml
#     [✓] CLEAN
# [▶] Scanning: krahets_hello-algo__typescript.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___compile_integration_test.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___integration_test.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___lint.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___release.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___test.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___test_doc_imports.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___test_pydantic.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain___test_release.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__api_doc_build.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__check-broken-links.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__check_core_versions.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__check_diffs.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__check_new_docs.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__codespell.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__codspeed.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__people.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__run_notebooks.yml
#     [✓] CLEAN
# [▶] Scanning: langchain-ai_langchain__scheduled_test.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__api-tests.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__build-push.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__db-migration-test.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__deploy-dev.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__deploy-enterprise.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__deploy-rag-dev.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__docker-build.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__stale.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__style.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__tool-test-sdks.yaml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__translate-i18n-base-on-english.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__vdb-tests.yml
#     [✓] CLEAN
# [▶] Scanning: langgenius_dify__web-tests.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_PowerToys__dependency-review.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_PowerToys__msstore-submissions.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_PowerToys__package-submissions.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_PowerToys__spelling2.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__accept-baselines-fix-lints.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__ci.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__close-issues.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__copilot-setup-steps.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__create-cherry-pick-pr.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__error-deltas-watchdog.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__insiders.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__lkg.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__new-release-branch.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__nightly.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__pr-modified-files.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__release-branch-artifact.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__scorecard.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__set-version.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__sync-branch.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__sync-wiki.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__twoslash-repros.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_TypeScript__update-package-lock.yaml
#     [✓] CLEAN
# [▶] Scanning: microsoft_terminal__addToProject.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_terminal__spelling2.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_terminal__winget.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__basic.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__ci.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__monaco-editor.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__no-package-lock-changes.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__no-yarn-lock-changes.yml
#     [✓] CLEAN
# [▶] Scanning: microsoft_vscode__telemetry.yml
#     [✓] CLEAN
# [▶] Scanning: mrdoob_three.js__ci.yml
#     [✓] CLEAN
# [▶] Scanning: mrdoob_three.js__codeql-code-scanning.yml
#     [✓] CLEAN
# [▶] Scanning: mrdoob_three.js__read-size.yml
#     [✓] CLEAN
# [▶] Scanning: mrdoob_three.js__report-size.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__benchmark-destroy-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__benchmark-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__check-documentation-urls.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__check-pr-title.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__check-run-eligibility.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__chromatic.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__ci-master.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__ci-postgres-mysql.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__ci-pull-requests.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__docker-base-image.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__docker-build-push.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__docker-images-benchmark.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__e2e-flaky.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__e2e-reusable.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__e2e-tests-pr.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__e2e-tests.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__linting-reusable.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__notify-pr-status.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__release-create-pr.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__release-publish.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__release-push-to-channel.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__security-trivy-scan-callable.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__test-workflows-callable.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__test-workflows-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__test-workflows-pr-approved.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__test-workflows-pr-comment.yml
#     [✓] CLEAN
# [▶] Scanning: n8n-io_n8n__units-tests-reusable.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__auto-start-ci.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__build-tarball.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__close-stale-feature-requests.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__close-stale-pull-requests.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__close-stalled.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__comment-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__commit-lint.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__commit-queue.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__coverage-linux-without-intl.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__coverage-linux.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__coverage-windows.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__create-release-proposal.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__daily-wpt-fyi.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__daily.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__doc.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__find-inactive-collaborators.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__find-inactive-tsc.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__label-flaky-test-issue.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__label-pr.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__license-builder.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__lint-release-proposal.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__linters.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__major-release.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__notify-on-push.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__notify-on-review-wanted.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__scorecard.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__test-internet.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__test-linux.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__test-macos.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__timezone-update.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__tools.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__update-openssl.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__update-release-links.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__update-v8.yml
#     [✓] CLEAN
# [▶] Scanning: nodejs_node__update-wpt.yml
#     [✓] CLEAN
# [▶] Scanning: ohmyzsh_ohmyzsh__dependencies.yml
#     [✓] CLEAN
# [▶] Scanning: ohmyzsh_ohmyzsh__installer.yml
#     [✓] CLEAN
# [▶] Scanning: ohmyzsh_ohmyzsh__main.yml
#     [✓] CLEAN
# [▶] Scanning: ohmyzsh_ohmyzsh__project.yml
#     [✓] CLEAN
# [▶] Scanning: ollama_ollama__latest.yaml
#     [✓] CLEAN
# [▶] Scanning: ollama_ollama__release.yaml
#     [✓] CLEAN
# [▶] Scanning: ollama_ollama__test.yaml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__build-release.yml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__deploy-to-hf-spaces.yml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__docker-build.yaml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__format-backend.yaml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__format-build-frontend.yaml
#     [✓] CLEAN
# [▶] Scanning: open-webui_open-webui__release-pypi.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__build-and-push-dev-images.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__build-and-push-instantclient-images.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__build-and-push-nosql-image.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__build-and-push-nosql-sec-image.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__build-and-push-oci-cli-image.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_docker-images__super-linter.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__cdt-inspect.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__main.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__micronaut.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__ni-layers.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__quarkus.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__reachability-metadata.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_graal__spring.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__apiary.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__build.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__codeql-analysis.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__docker.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__javadoc.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_opengrok__release.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_truffleruby__ci.yml
#     [✓] CLEAN
# [▶] Scanning: oracle_truffleruby__prism.yml
#     [✓] CLEAN
# [▶] Scanning: ossu_computer-science__delete-empty-issues.yml
#     [✓] CLEAN
# [▶] Scanning: public-apis_public-apis__test_of_push_and_pull.yml
#     [✓] CLEAN
# [▶] Scanning: public-apis_public-apis__test_of_validate_package.yml
#     [✓] CLEAN
# [▶] Scanning: public-apis_public-apis__validate_links.yml
#     [✓] CLEAN
# [▶] Scanning: rust-lang_rust__ci.yml
#     [✓] CLEAN
# [▶] Scanning: rust-lang_rust__dependencies.yml
#     [✓] CLEAN
# [▶] Scanning: rust-lang_rust__ghcr.yml
#     [✓] CLEAN
# [▶] Scanning: rust-lang_rust__post-merge.yml
#     [✓] CLEAN
# [▶] Scanning: sindresorhus_awesome__main.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__arm-cd.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__arm-ci-extended-cpp.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__arm-ci-extended.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__arm-ci.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__cffconvert.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__issue-on-pr-rollback.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__osv-scanner-scheduled.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__pylint-presubmit.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__release-branch-cherrypick.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__scorecards-analysis.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__stale-issues.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__update-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: tensorflow_tensorflow__update-rbe.yml
#     [✓] CLEAN
# [▶] Scanning: trekhleb_javascript-algorithms__CI.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__browserstack.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__bundlewatch.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__calibreapp-image-actions.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__cspell.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__css.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__docs.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__issue-close-require.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__issue-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__js.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__lint.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__node-sass.yml
#     [✓] CLEAN
# [▶] Scanning: twbs_bootstrap__release-notes.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__build_and_deploy.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__build_and_test.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__build_reusable.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__cancel.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__code_freeze.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__force_merge_canary_release_pr.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__graphite_ci_optimizer.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__integration_tests_reusable.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__issue_bankrupt.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__issue_lock.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__issue_stale.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__issue_version.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__issue_wrong_template.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__notify_release.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__popular.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__pull_request_stats.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__retry_deploy_test.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__retry_test.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__rspack-nextjs-build-integration-tests.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__rspack-nextjs-dev-integration-tests.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__rspack-update-tests-manifest.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__setup-nextjs-build.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__test-turbopack-rust-bench-test.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__test_e2e_deploy_release.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__test_examples.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__triage.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__triage_with_ai.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__trigger_release.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__trigger_release_new.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__turbopack-benchmark.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__turbopack-nextjs-build-integration-tests.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__turbopack-nextjs-dev-integration-tests.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__turbopack-update-tests-manifest.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__update_fonts_data.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__update_react.yml
#     [✓] CLEAN
# [▶] Scanning: vercel_next.js__upload-tests-manifest.yml
#     [✓] CLEAN
# [▶] Scanning: vuejs_vue__ci.yml
#     [✓] CLEAN
# [▶] Scanning: vuejs_vue__release-tag.yml
#     [✓] CLEAN
# [▶] Scanning: yangshun_tech-interview-handbook__lint.yml
#     [✓] CLEAN
# [▶] Scanning: yangshun_tech-interview-handbook__tsc.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__build.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__core.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__download.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__issue-lockdown.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__quick-test.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__release-master.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__release-nightly.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__release.yml
#     [✓] CLEAN
# [▶] Scanning: yt-dlp_yt-dlp__sanitize-comment.yml
#     [✓] CLEAN
# [▶] Scanning: ytdl-org_youtube-dl__ci.yml
#     [✓] CLEAN
#
# [✅] Total workflows with issues: 1
# [📁] CSV saved to: ggshield_issue_status.csv

# %%
import re
import json
from pathlib import Path

modified_dir = Path("../tools_output/pinny/modified_workflow")
output_dir = Path("../tools_output/pinny/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

sha_pattern = re.compile(r"@([0-9a-fA-F]{7,40})")

saved = 0
skipped = []

files = list(modified_dir.glob("*.yml")) + list(modified_dir.glob("*.yaml"))

for modified_path in files:
    modified_lines = modified_path.read_text(encoding="utf-8").splitlines()
    findings = []

    for i, line in enumerate(modified_lines, start=1):
        if "uses:" in line and "@" in line:
            sha_match = sha_pattern.search(line)
            if sha_match:
                findings.append({
                    "rule": "unpinned-github-actions",
                    "pinned": line.strip(),
                    "line": i
                })

    if findings:
        # Normalize workflow name to always end with .yml
        workflow_name = modified_path.name
        if workflow_name.endswith(".yaml"):
            workflow_name = workflow_name[:-5] + ".yml"

        result = {
            "workflow": workflow_name,
            "tool": "pinny",
            "summary": {
                "total_findings": len(findings),
                "by_rule": {"unpinned-github-actions": len(findings)}
            },
            "findings": findings
        }

        # Save file with workflow_name + ".json"
        save_name = workflow_name + ".json"
        with open(output_dir / save_name, "w", encoding="utf-8") as out_f:
            json.dump(result, out_f, indent=2)

        saved += 1
    else:
        skipped.append(modified_path.name)

print(f"Saved {saved} normalized workflow result files to {output_dir}")
print(f"Skipped {len(skipped)} workflows with no findings:")
for name in skipped[:20]:
    print(f" - {name}")
# Out:
# Saved 544 normalized workflow result files to ../tools_output/pinny/workflow_with_issues
# Skipped 41 workflows with no findings:
#  - electron_electron__pipeline-electron-build-and-test-and-nan.yml
#  - huggingface_transformers__self-past-caller.yml
#  - Significant-Gravitas_AutoGPT__repo-pr-enforce-base-branch.yml
#  - huggingface_transformers__self-push-amd-mi210-caller.yml
#  - huggingface_transformers__self-scheduled-amd-caller.yml
#  - facebook_react__shared_cleanup_stale_branch_caches.yml
#  - microsoft_PowerToys__package-submissions.yml
#  - nodejs_node__update-release-links.yml
#  - microsoft_TypeScript__pr-modified-files.yml
#  - IBM_sarama__fvt-main.yml
#  - Significant-Gravitas_AutoGPT__repo-stats.yml
#  - electron_electron__pipeline-electron-build-and-test.yml
#  - vercel_next.js__rspack-nextjs-dev-integration-tests.yml
#  - n8n-io_n8n__test-workflows-nightly.yml
#  - nodejs_node__label-flaky-test-issue.yml
#  - huggingface_transformers__self-nightly-caller.yml
#  - vercel_next.js__turbopack-nextjs-build-integration-tests.yml
#  - yt-dlp_yt-dlp__issue-lockdown.yml
#  - IBM_sarama__cache-cleanup.yml
#  - vercel_next.js__rspack-nextjs-build-integration-tests.yml
