# %% [markdown]
# POUTINE _____________________________________________________________________________________________

# %% [markdown]
# ./poutine analyze_local . --format json > tools_output/poutine/findings.json

# %%
import os
import json
import subprocess
from pathlib import Path
from collections import defaultdict

# Paths (match the style of the actionlint script)
WORKFLOW_DIR = "../.github/workflows"
POUTINE = "./../tools/poutine/poutine"

RAW_JSON = Path("../tools_output/poutine/findings.json")
OUTPUT_DIR = Path("../tools_output/poutine/workflow_with_issues")

total_files_with_findings = 0

# 1) Run poutine once, save raw JSON (like: poutine ... --format json > findings.json)
RAW_JSON.parent.mkdir(parents=True, exist_ok=True)

try:
    completed = subprocess.run(
        [POUTINE, "analyze_local", "..", "--format", "json"],  # scan repo root (consistent with WORKFLOW_DIR="../.github/workflows")
        capture_output=True,
        text=True
    )

    stdout = (completed.stdout or "").strip()
    if not stdout:
        print("poutine produced no output, nothing to parse.")
        raise SystemExit(0)

    with open(RAW_JSON, "w", encoding="utf-8") as f_out:
        f_out.write(stdout)

except Exception as e:
    raise SystemExit(f"Error running poutine: {e}")

# 2) Create per-workflow outputs (folder created after findings.json exists)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Load raw findings
try:
    with open(RAW_JSON, "r", encoding="utf-8") as f:
        data = json.load(f)
except Exception as e:
    raise SystemExit(f"Error reading/parsing {RAW_JSON}: {e}")

all_findings = data.get("findings", [])

# Group findings by workflow file name (basename)
grouped = defaultdict(list)
for finding in all_findings:
    meta = finding.get("meta", {})
    path = meta.get("path")
    if not path:
        continue

    workflow_file = Path(path).name

    grouped[workflow_file].append({
        "rule_id": finding.get("rule_id", ""),
        "line": int(meta["line"]) if "line" in meta and str(meta["line"]).isdigit() else meta.get("line", ""),
        "column": "",  # poutine does not report columns
        "job": meta.get("job", ""),
        "step": meta.get("step", ""),
        "details": meta.get("details", ""),
        "event_triggers": meta.get("event_triggers", []),
    })

# Write one JSON file per workflow file (same structure style as actionlint script)
for file in sorted(os.listdir(WORKFLOW_DIR)):
    if file.endswith((".yml", ".yaml")):
        findings = grouped.get(file, [])
        if not findings:
            continue

        by_rule = {}
        for f in findings:
            rid = f.get("rule_id", "")
            if rid:
                by_rule[rid] = by_rule.get(rid, 0) + 1

        output_data = {
            "workflow": file,
            "tool": "poutine",
            "summary": {
                "total_findings": len(findings),
                "by_rule": by_rule
            },
            "findings": findings
        }

        output_path = OUTPUT_DIR / f"{file}.json"
        with open(output_path, "w", encoding="utf-8") as f_out:
            json.dump(output_data, f_out, indent=2)

        total_files_with_findings += 1

print(f"Wrote raw findings to {RAW_JSON}")
print(f"Saved findings for {total_files_with_findings} workflow files to {OUTPUT_DIR}")
# Out:
# Wrote raw findings to ../tools_output/poutine/findings.json
# Saved findings for 298 workflow files to ../tools_output/poutine/workflow_with_issues

# %% [markdown]
# ACTIONLINT ____________________________________________________________________________________

# %% [markdown]
# ./actionlint .github/workflows/*.yml > tools_output/actionlint/findings.txt

# %%
import os
import re
import json
import subprocess
from pathlib import Path
from collections import defaultdict

# Paths
WORKFLOW_DIR = "../.github/workflows"
ACTIONLINT = "./../tools/actionlint/actionlint"
OUTPUT_DIR = Path("../tools_output/actionlint/workflow_with_issues")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

total_files_with_findings = 0

for file in sorted(os.listdir(WORKFLOW_DIR)):
    if file.endswith((".yml", ".yaml")):
        file_path = os.path.join(WORKFLOW_DIR, file)

        # Run actionlint on a single file
        try:
            completed = subprocess.run(
                [ACTIONLINT, file_path],
                capture_output=True,
                text=True
            )
            stdout = completed.stdout.strip()
            if not stdout:
                continue  # No findings, skip

            findings = []
            for line in stdout.splitlines():
                # Example: ../.github/workflows/foo.yml:8:1: Some issue
                match = re.match(rf".+?{re.escape(file)}:(\d+):(\d+):\s+(.*)", line)
                if match:
                    line_num, col_num, message = match.groups()
                    findings.append({
                        "line": int(line_num),
                        "column": int(col_num),
                        "message": message.strip()
                    })

            if findings:
                output_data = {
                    "workflow": file,
                    "tool": "actionlint",
                    "summary": {
                        "total_findings": len(findings)
                    },
                    "findings": findings
                }

                output_path = OUTPUT_DIR / f"{file}.json"
                with open(output_path, "w", encoding="utf-8") as f_out:
                    json.dump(output_data, f_out, indent=2)
                total_files_with_findings += 1

        except Exception as e:
            print(f"Error processing {file}: {e}")

print(f"Saved findings for {total_files_with_findings} workflow files to {OUTPUT_DIR}")
# Out:
# Saved findings for 955 workflow files to ../tools_output/actionlint/workflow_with_issues

# %% [markdown]
# FRIZBEE _____________________________________________________________________________

# %% [markdown]
# ./frizbee actions -n > tools_output/frizbee/findings.txt

# %%
import os, shutil, subprocess, tempfile
from pathlib import Path
from datetime import datetime

# ---------- locate repo root ----------
cwd = Path.cwd()

def find_repo_root(p: Path) -> Path:
    for c in (p, p.parent, p.parent.parent):
        if (c / ".github" / "workflows").exists():
            return c
    raise RuntimeError("Could not find repo root containing .github/workflows")

REPO = find_repo_root(cwd)
WORKFLOWS_DIR = REPO / ".github" / "workflows"
FRIZBEE_BIN = REPO / "tools" / "frizbee" / "frizbee"  # adjust if needed

OUT_BASE = REPO / "tools_output" / "frizbee"
OUT_MOD  = OUT_BASE / "modified_workflows"
OUT_DIFF = OUT_BASE / "diffs"
OUT_LOGS = OUT_BASE / "logs"
for d in (OUT_MOD, OUT_DIFF, OUT_LOGS):
    d.mkdir(parents=True, exist_ok=True)

FAIL_LOG = OUT_BASE / "frizbee_failures.txt"
CSV_LOG  = OUT_BASE / "frizbee_summary.csv"

def run(cmd, cwd: Path, env: dict, timeout=1800):
    return subprocess.run(
        cmd, cwd=str(cwd), env=env,
        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True,
        timeout=timeout, check=False
    )

# ---------- sanity checks ----------
if not FRIZBEE_BIN.exists():
    raise FileNotFoundError(f"frizbee binary not found at: {FRIZBEE_BIN}")
if not WORKFLOWS_DIR.exists():
    raise FileNotFoundError(f"workflows dir not found at: {WORKFLOWS_DIR}")

workflows = sorted(list(WORKFLOWS_DIR.glob("*.yml")) + list(WORKFLOWS_DIR.glob("*.yaml")))
print(f"[i] Repo: {REPO}")
print(f"[i] Workflows: {len(workflows)}")
print(f"[i] Frizbee: {FRIZBEE_BIN}")

# GitHub token helps avoid API issues (optional but recommended)
env = os.environ.copy()
if "GITHUB_TOKEN" not in env or not env["GITHUB_TOKEN"]:
    print("[!] GITHUB_TOKEN not set. Frizbee may be slower/flakier if it needs GitHub API lookups.")

# init logs
FAIL_LOG.write_text("", encoding="utf-8")
if not CSV_LOG.exists():
    CSV_LOG.write_text("workflow,status,modified,notes\n", encoding="utf-8")

ok = failed = modified = 0

for wf in workflows:
    wf_name = wf.name
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")

    with tempfile.TemporaryDirectory(prefix="frizbee_onewf_") as tmp:
        tmp = Path(tmp)
        tmp_wf_dir = tmp / ".github" / "workflows"
        tmp_wf_dir.mkdir(parents=True, exist_ok=True)

        tmp_wf = tmp_wf_dir / wf_name
        shutil.copy2(wf, tmp_wf)

        # init minimal git repo (lets us diff cleanly)
        run(["git", "init", "-q"], cwd=tmp, env=env)
        run(["git", "config", "user.email", "bench@example.com"], cwd=tmp, env=env)
        run(["git", "config", "user.name", "bench"], cwd=tmp, env=env)
        run(["git", "add", str(tmp_wf)], cwd=tmp, env=env)
        run(["git", "commit", "-qm", "input"], cwd=tmp, env=env)

        # run frizbee on ONLY this one workflow (directory contains one file)
        # (no -n, because we want the modified version)
        cp = run([str(FRIZBEE_BIN), "actions", str(tmp_wf_dir)], cwd=tmp, env=env)

        # save logs per workflow
        (OUT_LOGS / f"{wf_name}.{ts}.stdout.txt").write_text(cp.stdout, encoding="utf-8", errors="replace")
        (OUT_LOGS / f"{wf_name}.{ts}.stderr.txt").write_text(cp.stderr, encoding="utf-8", errors="replace")

        if cp.returncode != 0:
            failed += 1
            tail = (cp.stderr or cp.stdout)[-800:].replace("\n", "\\n")
            with FAIL_LOG.open("a", encoding="utf-8") as f:
                f.write(f"{wf_name}\t{tail}\n")
            with CSV_LOG.open("a", encoding="utf-8") as f:
                f.write(f"{wf_name},FAIL,0,\"{tail}\"\n")
            continue

        diff_cp = run(["git", "diff", "--", str(tmp_wf)], cwd=tmp, env=env)
        changed = bool(diff_cp.stdout.strip())

        if changed:
            modified += 1
            shutil.copy2(tmp_wf, OUT_MOD / wf_name)
            (OUT_DIFF / f"{wf_name}.patch").write_text(diff_cp.stdout, encoding="utf-8", errors="replace")
            notes = "modified"
        else:
            notes = "no-change"

        ok += 1
        with CSV_LOG.open("a", encoding="utf-8") as f:
            f.write(f"{wf_name},OK,{1 if changed else 0},{notes}\n")

print("\n=== frizbee summary ===")
print("OK:", ok)
print("FAILED:", failed)
print("MODIFIED:", modified)
print("Modified workflows:", OUT_MOD)
print("Diff patches:", OUT_DIFF)
print("Logs:", OUT_LOGS)
print("Failures:", FAIL_LOG)
print("CSV:", CSV_LOG)
# Out:
# [i] Repo: /home/huawei/github-actions-security
# [i] Workflows: 2722
# [i] Frizbee: /home/huawei/github-actions-security/tools/frizbee/frizbee
#
# === frizbee summary ===
# OK: 2722
# FAILED: 0
# MODIFIED: 1646
# Modified workflows: /home/huawei/github-actions-security/tools_output/frizbee/modified_workflows
# Diff patches: /home/huawei/github-actions-security/tools_output/frizbee/diffs
# Logs: /home/huawei/github-actions-security/tools_output/frizbee/logs
# Failures: /home/huawei/github-actions-security/tools_output/frizbee/frizbee_failures.txt
# CSV: /home/huawei/github-actions-security/tools_output/frizbee/frizbee_summary.csv

# %%
import re
import json
from pathlib import Path

# Paths
original_dir = Path("../.github/workflows")
modified_dir = Path("../tools_output/frizbee/modified_workflows")
output_dir = Path("../tools_output/frizbee/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Pattern to detect pinned actions with hash and version comment
pattern_actions = re.compile(r"uses:\s+([\w\-./]+)@([a-f0-9]{10,40})\s+#\s*(\S+)", re.IGNORECASE)
pattern_docker  = re.compile(r"uses:\s+(docker://\S+?)@(sha256:[a-f0-9]{20,})\s+#\s*(\S+)", re.IGNORECASE)


# Gather workflow names directly from modified_workflows directory
modified_files = [p.name for p in modified_dir.glob("*.yml")] + [p.name for p in modified_dir.glob("*.yaml")]

saved = 0

for wf_name in modified_files:
    original_path = original_dir / wf_name
    modified_path = modified_dir / wf_name

    if not original_path.exists() or not modified_path.exists():
        print(f"[!] Skipped: {wf_name} (missing original or modified)")
        continue

    original_lines = original_path.read_text(encoding="utf-8").splitlines()
    modified_lines = modified_path.read_text(encoding="utf-8").splitlines()

    findings = []

    # Compare line by line
    for i, (orig, mod) in enumerate(zip(original_lines, modified_lines)):

        m_docker = pattern_docker.search(mod)
        if m_docker:
            image_url, digest, tag = m_docker.groups()

            # Normalize docker image name for matching
            img = image_url[len("docker://"):]
            if img.startswith("index.docker.io/"):
                img_short = img[len("index.docker.io/"):]
            else:
                img_short = img

            # Original commonly uses ":tag"
            expected1 = f"docker://{img_short}:{tag}"
            expected2 = f"docker://index.docker.io/{img_short}:{tag}"

            if expected1 in orig or expected2 in orig:
                findings.append({
                    "rule": "unpinned-docker-image",
                    "original": expected1 if expected1 in orig else expected2,
                    "pinned": f"docker://index.docker.io/{img_short}@{digest}",
                    "line": i + 1
                })
            continue

        m_act = pattern_actions.search(mod)
        if m_act:
            action, sha, tag = m_act.groups()
            expected_unpinned = f"{action}@{tag}"
            actual_pinned = f"{action}@{sha}"
            if expected_unpinned in orig:
                findings.append({
                    "rule": "unpinned-github-actions",
                    "original": expected_unpinned,
                    "pinned": actual_pinned,
                    "line": i + 1
                })


    if not findings:
        continue

    summary = {
        "total_findings": len(findings),
        "by_rule": {"unpinned-github-actions": len(findings)}
    }

    result = {
        "workflow": wf_name,
        "tool": "frizbee",
        "summary": summary,
        "findings": findings
    }

    with open(output_dir / f"{wf_name}.json", "w", encoding="utf-8") as out_f:
        json.dump(result, out_f, indent=2)
        saved += 1

print(f"Saved {saved} normalized workflow result files to {output_dir}")
# Out:
# Saved 1646 normalized workflow result files to ../tools_output/frizbee/workflow_with_issues

# %% [markdown]
# SCHARF _______________________________________________________________________________

# %% [markdown]
# ./scharf audit . > tools_output/scharf/findings.txt

# %%
import os
import re
import json
import subprocess
from pathlib import Path
from collections import defaultdict

# Paths (same overall style as the actionlint / poutine scripts)
WORKFLOW_DIR = "../.github/workflows"
SCHARF = "./../tools/scharf/scharf"

RAW_TXT = Path("../tools_output/scharf/findings.txt")
OUTPUT_DIR = Path("../tools_output/scharf/workflow_with_issues")

# Regex to remove ANSI escape codes
ansi_escape = re.compile(r"\x1B\[[0-?]*[ -/]*[@-~]")

total_files_with_findings = 0

# 1) Run scharf once, save raw text (like: scharf audit . > findings.txt)
RAW_TXT.parent.mkdir(parents=True, exist_ok=True)

try:
    completed = subprocess.run(
        [SCHARF, "audit", ".."],  # scan repo root (consistent with WORKFLOW_DIR="../.github/workflows")
        capture_output=True,
        text=True
    )

    stdout = (completed.stdout or "").strip()
    if not stdout:
        print("scharf produced no output, nothing to parse.")
        raise SystemExit(0)

    with open(RAW_TXT, "w", encoding="utf-8") as f_out:
        f_out.write(stdout)

except Exception as e:
    raise SystemExit(f"Error running scharf: {e}")

# 2) Create per-workflow outputs (folder created after findings.txt exists)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Read and clean lines
lines = []
with open(RAW_TXT, "r", encoding="utf-8") as f:
    for raw in f:
        clean = ansi_escape.sub("", raw).strip()
        if clean:
            lines.append(clean)

# Parse and group
grouped = defaultdict(list)
current_workflow = None

for line in lines:
    # Detect workflow line
    if line.endswith(".yml") or line.endswith(".yaml"):
        current_workflow = Path(line).name
        continue

    # Detect and parse issue line
    if current_workflow and "[Line" in line:
        match = re.search(r"\[Line (\d+), Col (\d+)\] (.+)", line)
        if match:
            line_num, col_num, message = match.groups()
            grouped[current_workflow].append({
                "line": int(line_num),
                "column": int(col_num),
                "message": message
            })

# 3) Write one JSON file per workflow (same structure style as actionlint)
for file in sorted(os.listdir(WORKFLOW_DIR)):
    if file.endswith((".yml", ".yaml")):
        findings = grouped.get(file, [])
        if not findings:
            continue

        output_data = {
            "workflow": file,
            "tool": "scharf",
            "summary": {
                "total_findings": len(findings),
                "by_rule": {
                    "unpinned-github-actions": len(findings)
                }
            },
            "findings": findings
        }

        out_path = OUTPUT_DIR / f"{file}.json"
        with open(out_path, "w", encoding="utf-8") as f_out:
            json.dump(output_data, f_out, indent=2)

        total_files_with_findings += 1

print(f"Wrote raw findings to {RAW_TXT}")
print(f"Saved findings for {total_files_with_findings} workflow files to {OUTPUT_DIR}")
# Out:
# Wrote raw findings to ../tools_output/scharf/findings.txt
# Saved findings for 2161 workflow files to ../tools_output/scharf/workflow_with_issues

# %% [markdown]
# PINNY ___________________________________________________________________________

# %% [markdown]
# ./pinny actions pin --dry-run > tools_output/pinny/findings.txt

# %%
import os
import shutil
import subprocess
import tempfile
from pathlib import Path
from datetime import datetime

# ---------- locate repo root ----------
def find_repo_root() -> Path:
    for c in (Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent):
        if (c / ".github" / "workflows").exists():
            return c
    raise RuntimeError("Could not find repo root containing .github/workflows")

REPO = find_repo_root()
WORKFLOWS_DIR = REPO / ".github" / "workflows"
PINNY_BIN = REPO / "tools" / "pinny" / "pinny"

OUT_BASE = REPO / "tools_output" / "pinny"
OUT_MOD  = OUT_BASE / "modified_workflows"
OUT_LOGS = OUT_BASE / "logs"
for d in (OUT_MOD, OUT_LOGS):
    d.mkdir(parents=True, exist_ok=True)

SKIP_LOG = OUT_BASE / "pinny_skipped_crashers.txt"
SUMMARY  = OUT_BASE / "pinny_summary.txt"

def run(cmd, cwd: Path, env: dict, timeout=900):
    return subprocess.run(
        cmd,
        cwd=str(cwd),
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        timeout=timeout,
        check=False,
    )

# ---------- sanity checks ----------
if not PINNY_BIN.exists():
    raise FileNotFoundError(f"pinny binary not found at: {PINNY_BIN}")
if not WORKFLOWS_DIR.exists():
    raise FileNotFoundError(f"workflows dir not found at: {WORKFLOWS_DIR}")

workflows = sorted(list(WORKFLOWS_DIR.glob("*.yml")) + list(WORKFLOWS_DIR.glob("*.yaml")))
print(f"[i] Repo: {REPO}")
print(f"[i] Workflows: {len(workflows)}")
print(f"[i] Pinny: {PINNY_BIN}")

# ---------- load GITHUB_TOKEN from ../.env (notebook-safe) ----------
def load_env_file(p: Path) -> dict:
    env = {}
    if not p.exists():
        return env
    for line in p.read_text(encoding="utf-8", errors="replace").splitlines():
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        if line.lower().startswith("export "):
            line = line[7:].strip()
        if "=" not in line:
            continue
        k, v = line.split("=", 1)
        env[k.strip()] = v.strip().strip('"').strip("'")
    return env

env = os.environ.copy()

cwd = Path.cwd()
dotenv_candidates = [
    cwd.parent / ".env",   # your case: ../.env
    cwd / ".env",
    REPO / ".env",
    REPO.parent / ".env",
]
dotenv_path = next((p for p in dotenv_candidates if p.exists()), None)
dotenv_vars = load_env_file(dotenv_path) if dotenv_path else {}

if "GITHUB_TOKEN" not in env or not env["GITHUB_TOKEN"]:
    tok = dotenv_vars.get("GITHUB_TOKEN") or dotenv_vars.get("GH_TOKEN")
    if tok:
        env["GITHUB_TOKEN"] = tok

print(f"[i] dotenv_path: {dotenv_path if dotenv_path else 'none'}")
print(f"[i] GITHUB_TOKEN present: {bool(env.get('GITHUB_TOKEN'))}")
if not env.get("GITHUB_TOKEN"):
    print("[!] Warning: GITHUB_TOKEN not set. Pinny may hit GitHub API rate limits.")

# ---------- init logs ----------
SKIP_LOG.write_text("", encoding="utf-8")

ok = failed = modified = 0

for i, wf in enumerate(workflows, 1):
    wf_name = wf.name
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"[{i}/{len(workflows)}] {wf_name}")

    with tempfile.TemporaryDirectory(prefix="pinny_onewf_") as td:
        tmp = Path(td)
        tmp_wf_dir = tmp / ".github" / "workflows"
        tmp_wf_dir.mkdir(parents=True, exist_ok=True)

        tmp_wf = tmp_wf_dir / wf_name
        shutil.copy2(wf, tmp_wf)

        before_bytes = tmp_wf.read_bytes()

        # run pinny at temp repo root
        cp = run([str(PINNY_BIN), "actions", "pin"], cwd=tmp, env=env, timeout=900)

        # save logs per workflow
        (OUT_LOGS / f"{wf_name}.{ts}.stdout.txt").write_text(cp.stdout or "", encoding="utf-8", errors="replace")
        (OUT_LOGS / f"{wf_name}.{ts}.stderr.txt").write_text(cp.stderr or "", encoding="utf-8", errors="replace")

        if cp.returncode != 0:
            failed += 1
            with SKIP_LOG.open("a", encoding="utf-8") as f:
                f.write(f"{wf_name}\n")
            continue

        after_bytes = tmp_wf.read_bytes()
        if after_bytes != before_bytes:
            modified += 1
            shutil.copy2(tmp_wf, OUT_MOD / wf_name)

        ok += 1

summary_txt = (
    "=== pinny summary ===\n"
    f"Total workflows: {len(workflows)}\n"
    f"OK scans:        {ok}\n"
    f"FAILED scans:    {failed}  (listed in {SKIP_LOG})\n"
    f"MODIFIED files:  {modified} (saved in {OUT_MOD})\n"
    f"Logs folder:     {OUT_LOGS}\n"
)
SUMMARY.write_text(summary_txt, encoding="utf-8")
print("\n" + summary_txt)
# Out:
# [i] Repo: /home/huawei/github-actions-security
# [i] Workflows: 2722
# [i] Pinny: /home/huawei/github-actions-security/tools/pinny/pinny
# [i] dotenv_path: /home/huawei/github-actions-security/.env
# [i] GITHUB_TOKEN present: True
# [1/2722] Azure_AKS__.github__workflows__codespell.yml
# [2/2722] Azure_AKS__.github__workflows__website-check.yml
# [3/2722] Azure_AKS__.github__workflows__website-publish.yml
# [4/2722] Azure_Azure-Sentinel__.github__workflows__AddLabel.yaml
# [5/2722] Azure_Azure-Sentinel__.github__workflows__IssueComment.yml
# [6/2722] Azure_Azure-Sentinel__.github__workflows__ScanSecrets.yaml
# [7/2722] Azure_Azure-Sentinel__.github__workflows__addComment.yaml
# [8/2722] Azure_Azure-Sentinel__.github__workflows__addCommentOnPackagedPR.yaml
# [9/2722] Azure_Azure-Sentinel__.github__workflows__addCommentToRemindUpdatingTemplateVersion.yml
# [10/2722] Azure_Azure-Sentinel__.github__workflows__addLabelOnPr.yaml
# ...

# %%
import re
import json
from pathlib import Path

modified_dir = Path("../tools_output/pinny/modified_workflows")
output_dir = Path("../tools_output/pinny/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# existing: GitHub action pinned to SHA
sha_pattern = re.compile(r"@([0-9a-fA-F]{7,40})\b")

# NEW: docker digest pinning
docker_digest_pattern = re.compile(r"uses:\s+docker://\S+@sha256:[0-9a-fA-F]{20,}", re.IGNORECASE)

saved = 0
skipped = []

files = list(modified_dir.glob("*.yml")) + list(modified_dir.glob("*.yaml"))

for modified_path in files:
    modified_lines = modified_path.read_text(encoding="utf-8").splitlines()
    findings = []

    for i, line in enumerate(modified_lines, start=1):
        if "uses:" in line and "@" in line:
            # NEW: docker digest
            if docker_digest_pattern.search(line):
                findings.append({
                    "rule": "unpinned-docker-image",
                    "pinned": line.strip(),
                    "line": i
                })
                continue

            # existing: action pinned SHA
            sha_match = sha_pattern.search(line)
            if sha_match:
                findings.append({
                    "rule": "unpinned-github-actions",
                    "pinned": line.strip(),
                    "line": i
                })

    if findings:
        workflow_name = modified_path.name
        if workflow_name.endswith(".yaml"):
            workflow_name = workflow_name[:-5] + ".yml"

        # count per rule
        by_rule = {}
        for f in findings:
            by_rule[f["rule"]] = by_rule.get(f["rule"], 0) + 1

        result = {
            "workflow": workflow_name,
            "tool": "pinny",
            "summary": {
                "total_findings": len(findings),
                "by_rule": by_rule
            },
            "findings": findings
        }

        # avoid overwrite and double extensions
        save_name = modified_path.name + ".json"
        with open(output_dir / save_name, "w", encoding="utf-8") as out_f:
            json.dump(result, out_f, indent=2)

        saved += 1
    else:
        skipped.append(modified_path.name)

print(f"Saved {saved} normalized workflow result files to {output_dir}")
print(f"Skipped {len(skipped)} workflows with no findings:")
for name in skipped[:20]:
    print(f" - {name}")
# Out:
# Saved 2129 normalized workflow result files to ../tools_output/pinny/workflow_with_issues
# Skipped 10 workflows with no findings:
#  - microsoft_terminal__.github__workflows__winget.yml
#  - microsoft_winget-cli__.github__workflows__spelling2.yml
#  - microsoft_winget-cli__.github__workflows__spelling.yml
#  - awslabs_agent-squad__.github__workflows__on-push.yml
#  - microsoft_vscode-cpptools__.github__workflows__ci_linux.yml
#  - microsoft_vscode-cpptools__.github__workflows__ci_windows.yml
#  - microsoft_vscode-cpptools__.github__workflows__ci_mac.yml
#  - Tencent_Hippy__.github__workflows__hip_info_artifacts.yml
#  - Azure_Azure-Sentinel__.github__workflows__checkAutomatedPR.yaml
#  - microsoft_VFSForGit__.github__workflows__release-winget.yaml

# %% [markdown]
# ZIZMOR ________________________________________________________________________________

# %% [markdown]
# ./zizmor .github/workflows > tools_output/zizmor/findings.txt

# %%
import os
import subprocess
from pathlib import Path

WORKFLOW_DIR = "../.github/workflows"
ZIZMOR = "./../tools/zizmor/zizmor"
RAW_DIR = Path("../tools_output/zizmor/raw_logs")
RAW_DIR.mkdir(parents=True, exist_ok=True)

for file in sorted(os.listdir(WORKFLOW_DIR)):
    if not file.endswith((".yml", ".yaml")):
        continue

    file_path = os.path.join(WORKFLOW_DIR, file)
    out_path = RAW_DIR / f"{file}.txt"

    try:
        with open(out_path, "w", encoding="utf-8") as out:
            subprocess.run(
                [ZIZMOR, file_path],
                stdout=out,
                stderr=subprocess.DEVNULL,
                text=True
            )
        print(f"✅ Saved findings: {file}")
    except Exception as e:
        print(f"❌ Failed on {file}: {e}")
# Out:
# ✅ Saved findings: Azure_AKS__.github__workflows__codespell.yml
# ✅ Saved findings: Azure_AKS__.github__workflows__website-check.yml
# ✅ Saved findings: Azure_AKS__.github__workflows__website-publish.yml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__AddLabel.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__IssueComment.yml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__ScanSecrets.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__addComment.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__addCommentOnPackagedPR.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__addCommentToRemindUpdatingTemplateVersion.yml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__addLabelOnPr.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__allowedWorkflowRun.yaml
# ✅ Saved findings: Azure_Azure-Sentinel__.github__workflows__arm-ttk-validations.yaml
# ...

# %%
import re
import json
from pathlib import Path

# Paths
input_dir = Path("../tools_output/zizmor/raw_logs")
output_dir = Path("../tools_output/zizmor/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Regex patterns
ansi_escape = re.compile(r"\x1B\[[0-?]*[ -/]*[@-~]")  # standard ANSI colors
osc8_link = re.compile(r"\x1b]8;;[^\x1b]*\x1b\\(.*?)\x1b]8;;\x1b\\")  # hyperlinks
finding_pattern = re.compile(r"(info|warning|error)\[(.+?)\]: (.+)")
# FIXED: allow optional "../" before .github
location_pattern = re.compile(r"-->\s+(?:\.\./)?\.github/workflows/(.+?):(\d+):(\d+)")
note_pattern = re.compile(r"= note: (.+)", re.IGNORECASE)

saved_files = 0

for input_file in input_dir.glob("*.txt"):
    findings = []
    current = {}
    workflow_file = input_file.stem

    with open(input_file, encoding="utf-8") as f:
        raw_lines = f.readlines()

    # Strip ANSI & hyperlinks
    clean_lines = []
    for line in raw_lines:
        line = ansi_escape.sub("", line)
        line = osc8_link.sub(r"\1", line)
        clean_lines.append(line.strip())

    if any("No findings to report" in line for line in clean_lines):
        continue

    for line in clean_lines:
        if not line:
            continue

        m = finding_pattern.match(line)
        if m:
            if current.get("rule_id"):
                findings.append(current)

            level, rule_id, message = m.groups()
            rule_id = osc8_link.sub(r"\1", rule_id)
            current = {
                "rule_id": rule_id.strip(),
                "level": level,
                "message": message.strip(),
                "workflow": workflow_file,
                "line": None,
                "column": None,
                "note": None
            }
            continue

        m = location_pattern.match(line)
        if m:
            _, line_num, col_num = m.groups()
            current["line"] = int(line_num)
            current["column"] = int(col_num)
            continue

        m = note_pattern.match(line)
        if m:
            current["note"] = m.group(1).strip()
            continue

    if current.get("rule_id"):
        findings.append(current)

    if not findings:
        continue

    rule_summary = {}
    for f in findings:
        rule_summary[f["rule_id"]] = rule_summary.get(f["rule_id"], 0) + 1

    result = {
        "workflow": workflow_file,
        "tool": "zizmor",
        "summary": {
            "total_findings": len(findings),
            "by_rule": rule_summary
        },
        "findings": findings
    }

    out_path = output_dir / f"{workflow_file}.json"
    with open(out_path, "w", encoding="utf-8") as out:
        json.dump(result, out, indent=2)

    saved_files += 1
    print(f"✅ {workflow_file} → {len(findings)} findings")

print(f"\n✅ Parsed {saved_files} workflow result files to {output_dir}")
# Out:
# ✅ google_comprehensive-rust__.github__workflows__publish.yml → 1 findings
# ✅ google_go-cmp__.github__workflows__test.yml → 1 findings
# ✅ microsoft_azurelinux__.github__workflows__check-srpm-duplicates.yml → 2 findings
# ✅ microsoft_playwright__.github__workflows__roll_stable_test_runner.yml → 4 findings
# ✅ microsoft_Olive__.github__workflows__docs.yml → 2 findings
# ✅ google_benchmark__.github__workflows__wheels.yml → 5 findings
# ✅ google_gson__.github__workflows__codeql-analysis.yml → 1 findings
# ✅ microsoft_agent-framework__.github__workflows__python-code-quality.yml → 10 findings
# ✅ microsoft_DirectXTK__.github__workflows__main.yml → 1 findings
# ✅ facebook_stylex__.github__workflows__benchmarks.yml → 7 findings
# ✅ Tencent_Hippy__.github__workflows__gh_pr_merge_guard.yml → 2 findings
# ✅ google_yapf__.github__workflows__pre-commit-autoupdate.yml → 2 findings
# ✅ NVIDIA_cuda-python__.github__workflows__release.yml → 23 findings
# ...

# %% [markdown]
# SCORECARD ___________________________________________________________________________________

# %% [markdown]
# ./scorecard --local=. > tools_output/scorecard/findings.txt

# %%
import os
import shutil
import subprocess
import json
from pathlib import Path
from tqdm import tqdm

# Paths
WORKFLOW_DIR = Path("../.github/workflows")
TEMP_REPO_DIR = Path("scorecard_tmp_repo")
FINDINGS_PATH = Path("../tools_output/scorecard/findings_all.json")
FINDINGS_PATH.parent.mkdir(parents=True, exist_ok=True)

# Clean previous run
if TEMP_REPO_DIR.exists():
    shutil.rmtree(TEMP_REPO_DIR)
TEMP_REPO_DIR.mkdir(parents=True)
(TEMP_REPO_DIR / ".github" / "workflows").mkdir(parents=True, exist_ok=True)

all_workflow_results = []

yml_files = list(WORKFLOW_DIR.glob("*.yml")) + list(WORKFLOW_DIR.glob("*.yaml"))
print(f"Running Scorecard simulation on {len(yml_files)} workflows...")

for wf in tqdm(yml_files, desc="Simulating"):
    # Clean temp workflows folder
    temp_wf_dir = TEMP_REPO_DIR / ".github" / "workflows"
    for f in temp_wf_dir.glob("*"):
        f.unlink()

    # Copy workflow into temp repo
    temp_wf_path = temp_wf_dir / wf.name
    shutil.copy(wf, temp_wf_path)

    # Run Scorecard
    result = subprocess.run(
        ["../tools/scorecard/scorecard", f"--local={TEMP_REPO_DIR}", "--show-details", "--format=json"],
        capture_output=True,
        text=True
    )

    try:
        json_data = json.loads(result.stdout)
    except json.JSONDecodeError:
        continue

    json_data["workflow"] = wf.name
    all_workflow_results.append(json_data)

# Save all results to a single JSON file
with open(FINDINGS_PATH, "w", encoding="utf-8") as f:
    json.dump(all_workflow_results, f, indent=2)

print(f"[✓] All scorecard workflow results saved to: {FINDINGS_PATH}")
# Out:
# Running Scorecard simulation on 2722 workflows...
# Simulating: 100%|██████████| 2722/2722 [14:30<00:00,  3.13it/s]
# [✓] All scorecard workflow results saved to: ../tools_output/scorecard/findings_all.json

# %%
import json
import re
from pathlib import Path
from collections import defaultdict

# Paths
input_file = Path("../tools_output/scorecard/findings_all.json")
output_dir = Path("../tools_output/scorecard/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Relevant rules
relevant_rules = {
    "Dangerous-Workflow",
    "Pinned-Dependencies",
    "Token-Permissions",
    "SAST",
}

# Regex to capture line numbers like ":171"
line_regex = re.compile(r":(\d+)\b")

with open(input_file, "r", encoding="utf-8") as f:
    workflows_data = json.load(f)

saved = 0
for wf in workflows_data:
    workflow_name = wf.get("workflow")
    checks = wf.get("checks", [])
    findings = []

    for check in checks:
        name = check.get("name")
        score = check.get("score")
        if name in relevant_rules and score is not None and score < 10 and score != -1:
            raw_details = check.get("details") or []
            affected_lines = []
            for detail in raw_details:
                for m in line_regex.finditer(detail):
                    affected_lines.append(int(m.group(1)))

            findings.append({
                "rule": name,
                "score": score,
                "reason": check.get("reason"),
                "lines": sorted(set(affected_lines)),
                "raw_details": raw_details,
                "documentation": check.get("documentation", {})
            })

    if not findings:
        continue

    by_rule = defaultdict(int)
    for f in findings:
        by_rule[f["rule"]] += 1

    result = {
        "workflow": workflow_name,
        "tool": "scorecard",
        "summary": {
            "total_findings": len(findings),
            "by_rule": dict(by_rule)
        },
        "findings": findings
    }

    out_path = output_dir / f"{workflow_name}.json"
    with open(out_path, "w", encoding="utf-8") as f_out:
        json.dump(result, f_out, indent=2)
        saved += 1

print(f"Saved {saved} workflow files to {output_dir}")
# Out:
# Saved 2706 workflow files to ../tools_output/scorecard/workflow_with_issues

# %% [markdown]
# SEMGREP _________________________________________________________________________________________

# %% [markdown]
# semgrep --config p/github-actions .github/workflows --json > tools_output/semgrep/findings.json

# %%
import os
import json
import subprocess
from pathlib import Path
from collections import defaultdict

# Paths (same style as your actionlint / poutine scripts)
WORKFLOW_DIR = "../.github/workflows"
SEMGREP = "semgrep"

RAW_JSON = Path("../tools_output/semgrep/findings.json")
OUTPUT_DIR = Path("../tools_output/semgrep/workflow_with_issues")

total_files_with_findings = 0

# 1) Run semgrep once, save raw JSON (equivalent to: semgrep ... --json > findings.json)
RAW_JSON.parent.mkdir(parents=True, exist_ok=True)

# Build the exact targets you want (workflows only)
workflow_paths = sorted(
    [str(p) for p in Path(WORKFLOW_DIR).glob("*.yml")]
    + [str(p) for p in Path(WORKFLOW_DIR).glob("*.yaml")]
)

if not workflow_paths:
    raise SystemExit(f"No workflow files found in: {WORKFLOW_DIR}")

try:
    completed = subprocess.run(
        [SEMGREP, "scan", "--config", "p/github-actions", "--json", *workflow_paths],
        capture_output=True,
        text=True
    )

    stdout = (completed.stdout or "").strip()

    # semgrep sometimes returns non-zero even when it prints JSON,
    # so we treat "no JSON output" as the real failure condition.
    if not stdout:
        err = (completed.stderr or "").strip()
        raise SystemExit(f"semgrep produced no JSON output.\n{err[:2000]}")

    with open(RAW_JSON, "w", encoding="utf-8") as f_out:
        f_out.write(stdout)

except Exception as e:
    raise SystemExit(f"Error running semgrep: {e}")

# 2) Create per-workflow outputs (folder created after findings.json exists)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Load Semgrep findings JSON
try:
    with open(RAW_JSON, "r", encoding="utf-8") as f:
        data = json.load(f)
except Exception as e:
    raise SystemExit(f"Error reading/parsing {RAW_JSON}: {e}")

# Group findings by workflow file (basename)
grouped = defaultdict(list)
for finding in data.get("results", []):
    path = Path(finding.get("path", ""))
    if not path.name:
        continue
    grouped[path.name].append(finding)

# Write one JSON per workflow file (same overall structure style as actionlint)
for file in sorted(os.listdir(WORKFLOW_DIR)):
    if file.endswith((".yml", ".yaml")):
        findings = grouped.get(file, [])
        if not findings:
            continue

        structured = []
        rule_counts = defaultdict(int)

        for f in findings:
            rule_id = f.get("check_id", "unknown").split(".")[-1]
            rule_counts[rule_id] += 1

            structured.append({
                "rule": rule_id,
                "line": f.get("start", {}).get("line"),
                "code": f.get("extra", {}).get("lines"),
                "note": f.get("extra", {}).get("message"),
                "documentation": f.get("extra", {}).get("shortlink")
            })

        output_data = {
            "workflow": file,
            "tool": "semgrep",
            "summary": {
                "total_findings": len(structured),
                "by_rule": dict(rule_counts)
            },
            "findings": structured
        }

        out_path = OUTPUT_DIR / f"{file}.json"
        with open(out_path, "w", encoding="utf-8") as f_out:
            json.dump(output_data, f_out, indent=2)

        total_files_with_findings += 1

print(f"Wrote raw findings to {RAW_JSON}")
print(f"Saved findings for {total_files_with_findings} workflow files to {OUTPUT_DIR}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 11
#       8 workflow_output_dir.mkdir(parents=True, exist_ok=True)
#      10 # Load Semgrep findings JSON
# ---> 11 with open(input_file, "r", encoding="utf-8") as f:
#      12     data = json.load(f)
#      14 # Group findings by file (workflow)
#
# File /mnt/c/32Madjda/Prof/Stage/Benoit/rtool/github-actions-security-sandbox/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# ...

# %% [markdown]
# GGSHIELD _______________________________________________________________________________________

# %% [markdown]
# ./ggshield secret scan --all-secrets path .github/workflows/ --recursive --json > tools_output/ggshield/findings.json

# %%
import json
from pathlib import Path

# Paths
input_path = Path("../tools_output/ggshield/findings.json")
output_dir = Path("../tools_output/ggshield/workflow_with_issues")
output_dir.mkdir(parents=True, exist_ok=True)

# Load JSON data
with open(input_path, "r", encoding="utf-8") as f:
    data = json.load(f)

saved = 0

# Extract and normalize
for entity in data.get("entities_with_incidents", []):
    incidents = entity.get("incidents", [])
    if not incidents:
        continue

    filename = Path(entity["filename"]).name
    findings = []

    for inc in incidents:
        rule = inc.get("policy", "secret-detected")
        documentation = inc.get("detector_documentation")
        note = inc.get("type")

        for occ in inc.get("occurrences", []):
            findings.append({
                "rule": rule,
                "line": occ.get("line_start"),
                "code": occ.get("match"),
                "note": note,
                "documentation": documentation
            })

    if not findings:
        continue

    # Build summary by rule
    by_rule = {}
    for finding in findings:
        r = finding["rule"]
        by_rule[r] = by_rule.get(r, 0) + 1

    result = {
        "workflow": filename,
        "tool": "ggshield",
        "summary": {
            "total_findings": len(findings),
            "by_rule": by_rule
        },
        "findings": findings
    }

    with open(output_dir / f"{filename}.json", "w", encoding="utf-8") as out_f:
        json.dump(result, out_f, indent=2)
        saved += 1

print(f"[✓] Saved {saved} normalized workflow result files to {output_dir}")
# Out:
# [INFO] Found 641 workflow files.
#
# [▶] Scanning: Azure_autorest__codeql.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_autorest__consitency-checks.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_autorest__prepare-auto-release-branch.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-powershell__issue-metrics.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-powershell__issue-sentinel.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-powershell__pr-labeled.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-quickstart-templates__auto-fix.yml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-rest-api-specs__SDK-Suppressions-Label.yaml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-rest-api-specs___reusable-eng-tools-test.yaml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-rest-api-specs___reusable-set-check-status.yaml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-rest-api-specs__arm-auto-signoff-code.yaml
#     [✓] CLEAN
# [▶] Scanning: Azure_azure-rest-api-specs__arm-auto-signoff-status.yaml
#     [✓] CLEAN
# ...
